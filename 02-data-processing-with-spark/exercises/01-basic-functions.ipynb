# %%
from pyspark.sql import SparkSession

spark = SparkSession.builder \
    .appName("Read Inside Airbnb data") \
    .getOrCreate()

# %%
listings = spark.read.csv("../data/listings.csv.gz", 
    header=True,
    inferSchema=True,
    sep=",", 
    quote='"',
    escape='"', 
    multiLine=True,
    mode="PERMISSIVE" 
)

# %%
listings.printSchema()
# Out:
# root
#  |-- id: long (nullable = true)
#  |-- listing_url: string (nullable = true)
#  |-- scrape_id: long (nullable = true)
#  |-- last_scraped: date (nullable = true)
#  |-- source: string (nullable = true)
#  |-- name: string (nullable = true)
#  |-- description: string (nullable = true)
#  |-- neighborhood_overview: string (nullable = true)
#  |-- picture_url: string (nullable = true)
#  |-- host_id: integer (nullable = true)
#  |-- host_url: string (nullable = true)
#  |-- host_name: string (nullable = true)
#  |-- host_since: date (nullable = true)
#  |-- host_location: string (nullable = true)
#  |-- host_about: string (nullable = true)
#  |-- host_response_time: string (nullable = true)
#  |-- host_response_rate: string (nullable = true)
#  |-- host_acceptance_rate: string (nullable = true)
#  |-- host_is_superhost: string (nullable = true)
#  |-- host_thumbnail_url: string (nullable = true)
#  |-- host_picture_url: string (nullable = true)
#  |-- host_neighbourhood: string (nullable = true)
#  |-- host_listings_count: integer (nullable = true)
#  |-- host_total_listings_count: integer (nullable = true)
#  |-- host_verifications: string (nullable = true)
#  |-- host_has_profile_pic: string (nullable = true)
#  |-- host_identity_verified: string (nullable = true)
#  |-- neighbourhood: string (nullable = true)
#  |-- neighbourhood_cleansed: string (nullable = true)
#  |-- neighbourhood_group_cleansed: string (nullable = true)
#  |-- latitude: double (nullable = true)
#  |-- longitude: double (nullable = true)
#  |-- property_type: string (nullable = true)
#  |-- room_type: string (nullable = true)
#  |-- accommodates: integer (nullable = true)
#  |-- bathrooms: double (nullable = true)
#  |-- bathrooms_text: string (nullable = true)
#  |-- bedrooms: integer (nullable = true)
#  |-- beds: integer (nullable = true)
#  |-- amenities: string (nullable = true)
#  |-- price: string (nullable = true)
#  |-- minimum_nights: integer (nullable = true)
#  |-- maximum_nights: integer (nullable = true)
#  |-- minimum_minimum_nights: integer (nullable = true)
#  |-- maximum_minimum_nights: integer (nullable = true)
#  |-- minimum_maximum_nights: integer (nullable = true)
#  |-- maximum_maximum_nights: integer (nullable = true)
#  |-- minimum_nights_avg_ntm: double (nullable = true)
#  |-- maximum_nights_avg_ntm: double (nullable = true)
#  |-- calendar_updated: string (nullable = true)
#  |-- has_availability: string (nullable = true)
#  |-- availability_30: integer (nullable = true)
#  |-- availability_60: integer (nullable = true)
#  |-- availability_90: integer (nullable = true)
#  |-- availability_365: integer (nullable = true)
#  |-- calendar_last_scraped: date (nullable = true)
#  |-- number_of_reviews: integer (nullable = true)
#  |-- number_of_reviews_ltm: integer (nullable = true)
#  |-- number_of_reviews_l30d: integer (nullable = true)
#  |-- availability_eoy: integer (nullable = true)
#  |-- number_of_reviews_ly: integer (nullable = true)
#  |-- estimated_occupancy_l365d: integer (nullable = true)
#  |-- estimated_revenue_l365d: integer (nullable = true)
#  |-- first_review: date (nullable = true)
#  |-- last_review: date (nullable = true)
#  |-- review_scores_rating: double (nullable = true)
#  |-- review_scores_accuracy: double (nullable = true)
#  |-- review_scores_cleanliness: double (nullable = true)
#  |-- review_scores_checkin: double (nullable = true)
#  |-- review_scores_communication: double (nullable = true)
#  |-- review_scores_location: double (nullable = true)
#  |-- review_scores_value: double (nullable = true)
#  |-- license: string (nullable = true)
#  |-- instant_bookable: string (nullable = true)
#  |-- calculated_host_listings_count: integer (nullable = true)
#  |-- calculated_host_listings_count_entire_homes: integer (nullable = true)
#  |-- calculated_host_listings_count_private_rooms: integer (nullable = true)
#  |-- calculated_host_listings_count_shared_rooms: integer (nullable = true)
#  |-- reviews_per_month: double (nullable = true)

# %%
# 1. Get a non-null picture URL for any property ("picture_url" field)
# Select any non-null picture URL
from pyspark.sql.functions import col

listings \
    .select(col('picture_url')) \
    .dropna() \
    .limit(1) \
    .show(20, truncate = False)
# Out:
# +------------------------------------------------------------------------------------------------------+
# |picture_url                                                                                           |
# +------------------------------------------------------------------------------------------------------+
# |https://a0.muscache.com/pictures/miso/Hosting-13913/original/d755aa6d-cebb-4464-80be-2722c921e8d5.jpeg|
# +------------------------------------------------------------------------------------------------------+

# %%
# 2. Get number of properties that get more than 10 reviews per month
listings \
    .filter(col('reviews_per_month') > 10) \
    .count()
# Out:
# 66

# %%
# 3. Get properties that have more bathrooms than bedrooms
listings \
    .filter(col('bathrooms') > col('bedrooms')) \
    .select('name', 'bathrooms', 'bedrooms') \
    .show(10, truncate = False)
# Out:
# +----------------------------------------------+---------+--------+
# |name                                          |bathrooms|bedrooms|
# +----------------------------------------------+---------+--------+
# |Cosy Double studio in Zone 2 Hammersmith (1)  |1.5      |1       |
# |LONDON DETACHED HOUSE*ElecGates etc           |2.0      |1       |
# |Designer room Park Views 4 mins zone 1 station|1.5      |1       |
# |Maisonette in Central London Zone 1           |1.5      |1       |
# |West London,loft ensuite, 5min2tube           |1.5      |1       |
# |Shoreditch Loft                               |1.5      |1       |
# |Five minute walk to South Bank                |1.5      |1       |
# |Stunning double room own bathroom             |4.0      |1       |
# |Also five minutes to South Bank               |1.5      |1       |
# |Studio 20 min from center                     |1.0      |0       |
# +----------------------------------------------+---------+--------+
# only showing top 10 rows

# %%
# 4. Get properties where the price is greater than 5,000. Collect the result as a Python list
# Remember to convert a price into a number first!
from pyspark.sql.functions import regexp_replace

listings_with_price = listings \
  .withColumn('price_numeric', regexp_replace('price', '[$,]', '').cast('float'))

listings_with_price \
    .filter(col('price_numeric') > 5000) \
    .select('name', 'price') \
    .collect()
# Out:
# [Row(name='Room in a cosy flat. Central, clean', price='$8,000.00'),
#  Row(name='Spacious Private Ground Floor Room', price='$6,309.00'),
#  Row(name='No Longer Available', price='$53,588.00'),
#  Row(name='Bright & airy DoubleBed with EnSuite in Zone 2!', price='$74,100.00'),
#  Row(name='The Apartments by The Sloane Club, Two Bedroom Apt', price='$7,377.00'),
#  Row(name='The Apartments by The Sloane Club, L 2 Bedroom Apt', price='$7,377.00'),
#  Row(name='Single room. 7ft x 9ft - Over looking garden', price='$6,523.00'),
#  Row(name='Close To London Eye (TUR)', price='$6,666.00'),
#  Row(name='Beautiful 2 BR flat in Kilburn with free parking', price='$6,000.00'),
#  Row(name='Semi-detached mews house in Knightsbridge.', price='$7,019.00'),
#  Row(name='Affordable Spacious  Room on the edge of the city', price='$6,000.00'),
#  Row(name='Henry’s Townhouse, London', price='$6,500.00'),
#  Row(name='City Suite', price='$5,353.00'),
#  Row(name='Hyde Park Suite', price='$5,653.00'),
#  Row(name='SHORT WALK TO LONDON EYE - DOUBLE ROOM (SUR)', price='$50,000.00'),
#  Row(name='The Presidential - 6 bed - stunning elegance', price='$6,000.00'),
#  Row(name='Kensington Penthouse', price='$7,538.00'),
#  Row(name='Walk To London Eye - Double Room (FIL)', price='$11,412.00'),
#  Row(name='Resolve Apartment', price='$5,240.00'),
#  Row(name='Very Large and Splendid Terrace House in London', price='$8,000.00'),
#  Row(name='Luxurious penthouse Acton', price='$5,743.00'),
#  Row(name='Twin Room Close to London Eye (RHI)', price='$50,000.00'),
#  Row(name='Short Walk to London Eye (8V1)', price='$6,900.00'),
#  Row(name='Foxter Properties Chelsea', price='$12,000.00'),
#  Row(name='Close To London Eye', price='$22,824.00'),
#  Row(name='Close To London Eye', price='$65,000.00'),
#  Row(name="Stylish Earl's Court Getaway", price='$9,999.00'),
#  Row(name='Close to London Eye (BOL)', price='$58,000.00'),
#  Row(name='Contemporary Oasis in Paddington II', price='$9,999.00'),
#  Row(name='1. V02 Large Apartment; next to Piccadilly Circus!', price='$6,400.00'),
#  Row(name='Modern Sky-High Flat In North Acton', price='$9,999.00'),
#  Row(name='Zone 1 - Central London (JAM)', price='$25,106.00'),
#  Row(name='Your Elite Hyde Park Retreat 2-Bedroom Luxury Flat', price='$10,890.00'),
#  Row(name='CentralLondon Luxury for 5! 1Min from Paddington', price='$9,680.00'),
#  Row(name='Spacious, airy penthouse with stunning view', price='$30,812.00'),
#  Row(name='20% Off Monthly Business Relocation Stays Belsize', price='$15,000.00'),
#  Row(name='Ultra Luxe 4 Bed flat in Mayfair', price='$6,000.00'),
#  Row(name='Short Walk To London Eye (SUR)', price='$20,000.00'),
#  Row(name='Close to The Shard (TAI)', price='$10,001.00'),
#  Row(name='London luxury.', price='$9,660.00'),
#  Row(name='Walk To London Eye (CAN)', price='$10,307.00'),
#  Row(name='Short Walk to London Eye (TOK)', price='$28,000.00'),
#  Row(name='The Artists House', price='$15,143.00'),
#  Row(name='Walk To London Eye (BLZ)', price='$30,000.00'),
#  Row(name='Luxury Grade II Listed Mansion', price='$9,389.00'),
#  Row(name='Modern apartment Central London', price='$8,918.00'),
#  Row(name='Tranquil 2 Bedroom Apartment in East London', price='$9,999.00'),
#  Row(name='Outdoor kitchen', price='$7,034.00'),
#  Row(name='Charmante Wohnung mit Balkon', price='$6,924.00'),
#  Row(name='Southwood House', price='$9,999.00'),
#  Row(name='Silverings', price='$9,999.00'),
#  Row(name='Penthouse in the City of London', price='$9,000.00'),
#  Row(name='Very Central Room - Walk to Eye', price='$58,000.00'),
#  Row(name='Walk To London Eye', price='$6,391.00'),
#  Row(name='Walk To London Eye', price='$66,189.00'),
#  Row(name='The Prince Albert', price='$12,000.00'),
#  Row(name='Corporate ready - Combination of Flats  - Up to 56', price='$8,537.00'),
#  Row(name='5 Flats in Building | Zone 1 | 20 Guests | 10 Beds', price='$7,677.00'),
#  Row(name='Student Only, En-suite Room at South Bank', price='$8,000.00'),
#  Row(name='Standard Double Room Near Ebury Square Gardens LON', price='$11,952.00'),
#  Row(name='Stylish 2 Bed Flat in Battersea - Private Balcony', price='$10,004.00'),
#  Row(name='One Bedroom Apartment Near Watergate Walk LON', price='$11,952.00'),
#  Row(name='Notting Hill The One One One 3', price='$6,924.00'),
#  Row(name='Wien Orpington', price='$6,924.00'),
#  Row(name='Notting Hill Die Eins Eins Eins 6', price='$6,924.00'),
#  Row(name='Notting Hill Die Eins Eins Eins 1', price='$6,924.00'),
#  Row(name='Atemberaubende Wohnung, in der Nähe von East.', price='$6,924.00'),
#  Row(name='Notting Hill Die Eins Eins Eins 5', price='$6,924.00'),
#  Row(name='Notting Hill Die Eins Eins Eins 4', price='$6,924.00'),
#  Row(name='Lux 2 Bed in Canary Wharf close to Excel & O2', price='$1,085,147.00'),
#  Row(name='Cozy Studio-Nicene House', price='$6,865.00'),
#  Row(name='Luxuriöse 2 Bett Wohnung im Hotelstil in Notting.', price='$6,924.00'),
#  Row(name='The Lightwell Studio at Bramham Gardens', price='$9,999.00'),
#  Row(name='Student Only Bronze Studio IQ\xa0Vega', price='$5,104.00'),
#  Row(name='Student Only Bronze Studio UpperLevel Premium View', price='$8,480.00'),
#  Row(name='Student Only Premium Ensuite at Drapery Place', price='$8,411.00'),
#  Row(name='Student Only, Classic Ensuite Finsbury House', price='$7,448.00'),
#  Row(name='Minimalist 2BD Flat near Shoreditch High Street', price='$8,000.00'),
#  Row(name='Stylish Family Home with Garden in Peckham Rye', price='$9,999.00'),
#  Row(name='Private Penthouse Above the Crowds', price='$9,999.00'),
#  Row(name='Chic East London Stay with Outdoor Space', price='$9,999.00'),
#  Row(name='ABR - Spacious 2 -Bed Patio Retreat in Kennington', price='$9,999.00'),
#  Row(name="Floating on the Thames A Designer's Dream", price='$9,999.00'),
#  Row(name='Elegant Fulham Retreat with Private Garden', price='$10,032.00'),
#  Row(name='Elegant Queen’s Park Retreat with Balcony', price='$9,999.00'),
#  Row(name='Contemporary Stratford Escape', price='$9,999.00'),
#  Row(name='Modern Mezzanine Apartment in Covent Garden', price='$9,999.00'),
#  Row(name='Bright Two-Bed Flat in Covent Garden', price='$9,999.00'),
#  Row(name='Single Semi-Ensuite Room', price='$10,000.00'),
#  Row(name='Stylish 3-Bed Home with Garden in Dollis Hill', price='$10,028.00'),
#  Row(name='Elegant West London Home with Style', price='$9,999.00'),
#  Row(name='Belgravia Living – 2-Bed, 1-Bath Apartment with Ba', price='$10,020.00'),
#  Row(name='Belgravia Living – 2-Bed, 1-Bath Belgravia Flat', price='$9,999.00'),
#  Row(name='Belgravia Living – Bright 2-Bed, 1-Bath Apartment', price='$9,999.00'),
#  Row(name='Belgravia Living – 2-Bed, 1-Bath Home with Balcony', price='$9,999.00'),
#  Row(name='Belgravia Base: 2BR Flat Near Victoria Station', price='$9,999.00'),
#  Row(name='Central Belgravia 2BR Near Victoria', price='$10,020.00'),
#  Row(name='Functional Belgravia 2BR Flat Near Victoria', price='$10,020.00'),
#  Row(name='Belgravia Living - Contemporary 2BR Near Victoria', price='$10,020.00'),
#  Row(name='Convenient 2BR/1BA Flat in Belgravia', price='$9,999.00'),
#  Row(name='Simple Belgravia Base Near Transport', price='$9,999.00'),
#  Row(name='\u200bChiswick Studio Retreat with Private Balcony', price='$9,999.00'),
#  Row(name='Belgravia 2 BR Hideaway with Balcony', price='$9,999.00'),
#  Row(name='Central Belgravia 2BR Near Victoria', price='$9,999.00'),
#  Row(name='Stylish London Apartment in Trendy Peckham', price='$9,999.00')]

# %%
# 5. Get a list of properties with the following characteristics:
# * price < 150
# * more than 20 reviews
# * review_scores_rating > 4.5
# Consider using the "&" operator
listings_with_price \
    .filter((col('price_numeric') < 150) & (col('number_of_reviews') > 20) & (col('review_scores_rating') > 4.5)) \
    .select('name', 'price', 'number_of_reviews', 'review_scores_rating') \
    .collect()
# Out:
# [Row(name='Holiday London DB Room Let-on going', price='$70.00', number_of_reviews=55, review_scores_rating=4.85),
#  Row(name='Bright Chelsea  Apartment. Chelsea!', price='$149.00', number_of_reviews=97, review_scores_rating=4.8),
#  Row(name='You are GUARANTEED to love this', price='$90.00', number_of_reviews=730, review_scores_rating=4.87),
#  Row(name='SUNNY ROOM PRIVATE BATHROOM PLUS BREAKFAST', price='$61.00', number_of_reviews=387, review_scores_rating=4.77),
#  Row(name='SPACIOUS ROOM IN CONTEMPORARY STYLE FLAT', price='$49.00', number_of_reviews=72, review_scores_rating=4.97),
#  Row(name='Room with a view, shared flat,  central  Bankside', price='$96.00', number_of_reviews=137, review_scores_rating=4.7),
#  Row(name='You Will Save Money Here', price='$71.00', number_of_reviews=639, review_scores_rating=4.89),
#  Row(name='Quiet Comfortable Room in Fulham', price='$48.00', number_of_reviews=266, review_scores_rating=4.74),
#  Row(name='Pleasant Single Room in zone 1.', price='$50.00', number_of_reviews=456, review_scores_rating=4.81),
#  Row(name='Cosy Double studio in Zone 2 Hammersmith (6)', price='$78.00', number_of_reviews=221, review_scores_rating=4.73),
#  Row(name='Beautiful Small Studio Hammersmith', price='$79.00', number_of_reviews=263, review_scores_rating=4.71),
#  Row(name='Cosy Double studio in Zone 2 Hammersmith (1)', price='$78.00', number_of_reviews=173, review_scores_rating=4.71),
#  Row(name='Cosy Double studio in Zone 2 Hammersmith (4)', price='$89.00', number_of_reviews=227, review_scores_rating=4.63),
#  Row(name='Cosy Double studio in Zone 2 Hammersmith (3)', price='$79.00', number_of_reviews=229, review_scores_rating=4.69),
#  Row(name='NICE FAMILY HOME opposite NATURAL LANDSCAPED PARK', price='$40.00', number_of_reviews=25, review_scores_rating=4.54),
#  Row(name='2 bed/2 bath luxury flat with city view!', price='$117.00', number_of_reviews=110, review_scores_rating=4.9),
#  Row(name='Double Room 2 Miles from Wimbledon in Morden SM4', price='$35.00', number_of_reviews=169, review_scores_rating=4.9),
#  Row(name='Pretty Self Contained Coach House', price='$110.00', number_of_reviews=178, review_scores_rating=4.92),
#  Row(name='Clerkenwell penthouse, huge terrace', price='$125.00', number_of_reviews=77, review_scores_rating=4.95),
#  Row(name='Designer room Park Views 4 mins zone 1 station', price='$57.00', number_of_reviews=460, review_scores_rating=4.79),
#  Row(name='Maisonette in Central London Zone 1', price='$75.00', number_of_reviews=586, review_scores_rating=4.86),
#  Row(name='Lovely, spacious  garden apartment.', price='$145.00', number_of_reviews=232, review_scores_rating=4.8),
#  Row(name='Cosy, arty flat with roof terraces in Islington', price='$135.00', number_of_reviews=153, review_scores_rating=4.65),
#  Row(name='modern self contained flat islington', price='$90.00', number_of_reviews=339, review_scores_rating=4.85),
#  Row(name='Lovely Victorian Room Streatham', price='$60.00', number_of_reviews=47, review_scores_rating=4.86),
#  Row(name='Gorgeous Victorian Flat LONDON', price='$100.00', number_of_reviews=39, review_scores_rating=4.58),
#  Row(name='South Bank Bijou Studio Flat', price='$120.00', number_of_reviews=403, review_scores_rating=4.91),
#  Row(name='Lovely large room, Bethnal Green', price='$55.00', number_of_reviews=65, review_scores_rating=4.84),
#  Row(name='Double Room (Unavailable for check in 9-11 July)', price='$36.00', number_of_reviews=39, review_scores_rating=4.9),
#  Row(name='A stylish Victorian home in West London', price='$135.00', number_of_reviews=103, review_scores_rating=4.86),
#  Row(name='Apartment close to centre.', price='$105.00', number_of_reviews=152, review_scores_rating=4.77),
#  Row(name='Limehouse London, Spacious Property', price='$76.00', number_of_reviews=60, review_scores_rating=4.55),
#  Row(name='Clerkenwell double', price='$83.00', number_of_reviews=50, review_scores_rating=4.68),
#  Row(name='Sunny stylish flat, with frequently absent Host', price='$90.00', number_of_reviews=194, review_scores_rating=4.88),
#  Row(name='West London,loft ensuite, 5min2tube', price='$58.00', number_of_reviews=189, review_scores_rating=4.7),
#  Row(name="A double Room 5mins from King's College Hospital", price='$42.00', number_of_reviews=100, review_scores_rating=4.73),
#  Row(name='Bright&Huge room close to Southside Wandsworth', price='$39.00', number_of_reviews=22, review_scores_rating=4.79),
#  Row(name='The Residential Suite Above Gallery', price='$131.00', number_of_reviews=235, review_scores_rating=4.74),
#  Row(name='Quiet Double Room - Good for walks', price='$70.00', number_of_reviews=276, review_scores_rating=4.85),
#  Row(name='Private bathroom & spacious double room', price='$93.00', number_of_reviews=249, review_scores_rating=4.98),
#  Row(name='MODERN Self-Contained ARCHITECT FLAT', price='$108.00', number_of_reviews=39, review_scores_rating=4.85),
#  Row(name='Penthouse Living in East London', price='$45.00', number_of_reviews=42, review_scores_rating=4.65),
#  Row(name='London Whitechapel Room with WIFI', price='$44.00', number_of_reviews=289, review_scores_rating=4.78),
#  Row(name='Long Stay Cute Studio zone 1', price='$93.00', number_of_reviews=151, review_scores_rating=4.92),
#  Row(name='Private ensuite room in Harringay', price='$54.00', number_of_reviews=100, review_scores_rating=4.89),
#  Row(name='Room 20 min from central London', price='$36.00', number_of_reviews=22, review_scores_rating=4.64),
#  Row(name='Double room in family house - cost for 1 room only', price='$78.00', number_of_reviews=334, review_scores_rating=4.87),
#  Row(name='Bright sunny apartment on garden square', price='$95.00', number_of_reviews=71, review_scores_rating=4.74),
#  Row(name='one Double bed room with en-suite facilities', price='$53.00', number_of_reviews=28, review_scores_rating=5.0),
#  Row(name='Cozy double room', price='$66.00', number_of_reviews=337, review_scores_rating=4.85),
#  Row(name='Five minute walk to South Bank', price='$71.00', number_of_reviews=597, review_scores_rating=4.63),
#  Row(name='Stylish Garden Studio | Large Kitchen + Smart TV', price='$100.00', number_of_reviews=53, review_scores_rating=4.52),
#  Row(name='Homely room in leafy Ealing.', price='$40.00', number_of_reviews=643, review_scores_rating=4.8),
#  Row(name='One Bedroom Apartment', price='$116.00', number_of_reviews=25, review_scores_rating=4.52),
#  Row(name='One Bedroom Garden Apartment', price='$142.00', number_of_reviews=21, review_scores_rating=4.57),
#  Row(name='Also five minutes to South Bank', price='$66.00', number_of_reviews=563, review_scores_rating=4.63),
#  Row(name='Patio Apartment in London (Twickenham)', price='$74.00', number_of_reviews=88, review_scores_rating=4.64),
#  Row(name='Studio 20 min from center', price='$50.00', number_of_reviews=44, review_scores_rating=4.55),
#  Row(name='Georgian Apartment in Bloomsbury', price='$140.00', number_of_reviews=84, review_scores_rating=4.93),
#  Row(name='Spacious luxury 2 bedroom apartment', price='$95.00', number_of_reviews=25, review_scores_rating=4.6),
#  Row(name='Stylish apartment in trendy Dalston', price='$117.00', number_of_reviews=37, review_scores_rating=4.86),
#  Row(name='Large single bedroom nr Canning Town (7 mins bus)', price='$32.00', number_of_reviews=66, review_scores_rating=4.92),
#  Row(name='Single room near Canning Town (7 mins by bus)', price='$37.00', number_of_reviews=63, review_scores_rating=4.83),
#  Row(name='A people person awaits you here!', price='$48.00', number_of_reviews=79, review_scores_rating=4.9),
#  Row(name='Double room no 1 near Brunel, Uxbridge, Heathrow', price='$45.00', number_of_reviews=127, review_scores_rating=4.83),
#  Row(name='A Modern Double Room in Greenwich.', price='$38.00', number_of_reviews=397, review_scores_rating=4.96),
#  Row(name="peaceful double room 5mins from King's Hospital", price='$44.00', number_of_reviews=40, review_scores_rating=4.92),
#  Row(name='Double Room by Camden Market', price='$97.00', number_of_reviews=70, review_scores_rating=4.74),
#  Row(name='safe and spacious room in comfy family home', price='$26.00', number_of_reviews=138, review_scores_rating=4.83),
#  Row(name='Hotel-style room in Camden Town', price='$104.00', number_of_reviews=328, review_scores_rating=4.78),
#  Row(name='Fantastic location Double room', price='$95.00', number_of_reviews=39, review_scores_rating=4.87),
#  Row(name='Stylish, Light Central London Flat', price='$70.00', number_of_reviews=245, review_scores_rating=4.85),
#  Row(name='Light spacious apartment', price='$114.00', number_of_reviews=265, review_scores_rating=4.83),
#  Row(name='Spacious Double Room (R3)', price='$58.00', number_of_reviews=163, review_scores_rating=4.55),
#  Row(name='Superior Boutique Comfort, Amazing Fast Transport', price='$37.00', number_of_reviews=195, review_scores_rating=4.84),
#  Row(name='Beautiful warehouse flat in London', price='$95.00', number_of_reviews=31, review_scores_rating=4.7),
#  Row(name='Stylish 2 Bed Apartment with Balcony', price='$96.00', number_of_reviews=53, review_scores_rating=4.55),
#  Row(name='Shepherds Bush W12 Double/Twin Room', price='$60.00', number_of_reviews=337, review_scores_rating=4.89),
#  Row(name='NICE DOUBLE ROOM IN A CLEAN  AND QUIET HOUSE', price='$26.00', number_of_reviews=67, review_scores_rating=4.58),
#  Row(name='Homely Twin Room Streatham,London', price='$39.00', number_of_reviews=216, review_scores_rating=4.73),
#  Row(name='Homely Triple Room London 2', price='$39.00', number_of_reviews=247, review_scores_rating=4.78),
#  Row(name='1 bed flat near city.', price='$103.00', number_of_reviews=80, review_scores_rating=4.83),
#  Row(name='Canary Wharf/Excel riverside luxury', price='$135.00', number_of_reviews=21, review_scores_rating=5.0),
#  Row(name='Gorgeous double at Camden Market', price='$83.00', number_of_reviews=311, review_scores_rating=4.92),
#  Row(name='High rise flat in Angel Islington', price='$99.00', number_of_reviews=73, review_scores_rating=4.72),
#  Row(name='Bright airy double room, central', price='$32.00', number_of_reviews=261, review_scores_rating=4.65),
#  Row(name='Loft near Canning Town station (7 mins by bus)', price='$36.00', number_of_reviews=111, review_scores_rating=4.8),
#  Row(name='Double room in lovely period house - friendly host', price='$37.00', number_of_reviews=96, review_scores_rating=4.97),
#  Row(name='London Vauxhall - Excellent Option!', price='$138.00', number_of_reviews=334, review_scores_rating=4.9),
#  Row(name='Pristine 5 Star Double Room, 1 Guest, Central W1', price='$115.00', number_of_reviews=157, review_scores_rating=4.84),
#  Row(name='Vintage Oasis and Double Room and Peace', price='$51.00', number_of_reviews=157, review_scores_rating=4.88),
#  Row(name='Large sunny room, private bathroom, Dalston', price='$54.00', number_of_reviews=250, review_scores_rating=4.85),
#  Row(name='White Room in Classic London Town House - Zone 2', price='$90.00', number_of_reviews=60, review_scores_rating=4.7),
#  Row(name='Serene Room in Classic London Town House - Zone 2', price='$107.00', number_of_reviews=83, review_scores_rating=4.78),
#  Row(name="Large Dble Bdrm TV/Wifi nr NPL & St Mary's Uni", price='$45.00', number_of_reviews=239, review_scores_rating=4.95),
#  Row(name='Beautiful Victorian property on historic street', price='$57.00', number_of_reviews=107, review_scores_rating=4.94),
#  Row(name='Single bedroom', price='$50.00', number_of_reviews=53, review_scores_rating=4.65),
#  Row(name='Single room', price='$50.00', number_of_reviews=151, review_scores_rating=4.61),
#  Row(name='Heart of Notting Hill Garden Flat + cats', price='$80.00', number_of_reviews=171, review_scores_rating=4.77),
#  Row(name='Small single room', price='$23.00', number_of_reviews=105, review_scores_rating=4.7),
#  Row(name='MORDEN London Zone 4, Bright Single Room', price='$20.00', number_of_reviews=37, review_scores_rating=4.86),
#  Row(name='Comfortable/Friendly/Double room for 1/Limehouse', price='$38.00', number_of_reviews=179, review_scores_rating=4.94),
#  Row(name='Stylish Ensuite Room in house. - Maida Vale.', price='$83.00', number_of_reviews=144, review_scores_rating=4.88),
#  Row(name='Double room near tube', price='$50.00', number_of_reviews=73, review_scores_rating=4.99),
#  Row(name='Cozy room in lovely area!(Chiswick)', price='$72.00', number_of_reviews=30, review_scores_rating=4.97),
#  Row(name='Lovely Twin Room near to Common', price='$85.00', number_of_reviews=66, review_scores_rating=4.88),
#  Row(name='Lovely Smart Room', price='$53.00', number_of_reviews=490, review_scores_rating=4.84),
#  Row(name='Medium single room', price='$53.00', number_of_reviews=460, review_scores_rating=4.82),
#  Row(name='Twin-bedded sitting-room, 2 beds, 1 or 2 guests', price='$64.00', number_of_reviews=451, review_scores_rating=4.86),
#  Row(name='Sunny single free WiFi  Nr Richmond', price='$41.00', number_of_reviews=202, review_scores_rating=4.85),
#  Row(name='Maida Vale,Double bed with private garden   Zone 2', price='$63.00', number_of_reviews=153, review_scores_rating=4.95),
#  Row(name='Private Bedroom & Bathroom Peaceful & Central', price='$81.00', number_of_reviews=270, review_scores_rating=4.72),
#  Row(name='Double room in South London', price='$42.00', number_of_reviews=92, review_scores_rating=4.89),
#  Row(name='Pimlico Pad', price='$120.00', number_of_reviews=157, review_scores_rating=4.83),
#  Row(name='Beautiful Blue Room', price='$59.00', number_of_reviews=29, review_scores_rating=4.89),
#  Row(name='garden studio Ealing sleep up to 4', price='$87.00', number_of_reviews=176, review_scores_rating=4.79),
#  Row(name='Trendy London Double Room, Cafes and  Transport', price='$49.00', number_of_reviews=50, review_scores_rating=4.74),
#  Row(name='Super small double in stunning home', price='$40.00', number_of_reviews=74, review_scores_rating=4.78),
#  Row(name="Cosy and central St Luke's/Barbican single room", price='$74.00', number_of_reviews=185, review_scores_rating=4.94),
#  Row(name='DYNAMITE views!', price='$110.00', number_of_reviews=37, review_scores_rating=4.7),
#  Row(name='Lovely room in Clapton, Hackney E5', price='$73.00', number_of_reviews=66, review_scores_rating=4.77),
#  Row(name='Beautiful Penthouse in Clapham', price='$127.00', number_of_reviews=79, review_scores_rating=4.82),
#  Row(name='Entire quiet spacious home', price='$105.00', number_of_reviews=293, review_scores_rating=4.84),
#  Row(name='Bright Rooftop Nest In Notting Hill', price='$126.00', number_of_reviews=174, review_scores_rating=4.84),
#  Row(name='Large Double Room for Short/Long Stay selfcatering', price='$31.00', number_of_reviews=28, review_scores_rating=4.89),
#  Row(name='Lovely loft room with stylish en-suite.', price='$66.00', number_of_reviews=44, review_scores_rating=5.0),
#  Row(name='Lovely 2 bedroom flat near Brixton, zone 2, London', price='$135.00', number_of_reviews=23, review_scores_rating=4.77),
#  Row(name='Hackney Stylish & light 1 bedroom Victorian flat', price='$123.00', number_of_reviews=152, review_scores_rating=4.65),
#  Row(name='Large double bedroom in Shoreditch w/garden', price='$127.00', number_of_reviews=40, review_scores_rating=4.9),
#  Row(name='Double Room and Workspace in spacious Garden Flat', price='$54.00', number_of_reviews=254, review_scores_rating=4.75),
#  Row(name='Sunny double room/balcony/shower/wc', price='$55.00', number_of_reviews=260, review_scores_rating=4.96),
#  Row(name='London, Ealing, W13 Artists Home', price='$80.00', number_of_reviews=97, review_scores_rating=4.99),
#  Row(name='Attic Room in historic Greenwich', price='$41.00', number_of_reviews=335, review_scores_rating=4.79),
#  Row(name='202 double room shower Soho comfy', price='$90.00', number_of_reviews=537, review_scores_rating=4.58),
#  Row(name='Dream Apartment in central London', price='$62.00', number_of_reviews=542, review_scores_rating=4.83),
#  Row(name="Architect's pub conversion, London", price='$78.00', number_of_reviews=75, review_scores_rating=4.76),
#  Row(name='Ensuite room in artist lofty studio', price='$120.00', number_of_reviews=117, review_scores_rating=4.97),
#  Row(name='Spacious Double/Triple near Common', price='$85.00', number_of_reviews=75, review_scores_rating=4.79),
#  Row(name='Stunning large room (double sofa bed), Hackney, E9', price='$76.00', number_of_reviews=112, review_scores_rating=4.95),
#  Row(name='Peaceful loft in the trendy East End', price='$70.00', number_of_reviews=266, review_scores_rating=4.9),
#  Row(name='Great apartment in Hackney.', price='$77.00', number_of_reviews=67, review_scores_rating=4.86),
#  Row(name='Double Room Suiting Female Visitors to London', price='$43.00', number_of_reviews=57, review_scores_rating=4.96),
#  Row(name='Great Quirky Twin room in Wimbledon', price='$67.00', number_of_reviews=28, review_scores_rating=4.7),
#  Row(name='Surprisingly Spacious & Stylish 2 Bed, 2 Bath Flat', price='$127.00', number_of_reviews=281, review_scores_rating=4.78),
#  Row(name='En-suite room in modern 2 bed flat', price='$68.00', number_of_reviews=239, review_scores_rating=4.91),
#  Row(name='Double bedroom overlooking garden', price='$69.00', number_of_reviews=540, review_scores_rating=4.84),
#  Row(name='Double Room in Penthouse Flat', price='$135.00', number_of_reviews=125, review_scores_rating=4.54),
#  Row(name='Double Room in lovely family home', price='$56.00', number_of_reviews=139, review_scores_rating=4.97),
#  Row(name='Comfortable room to stay in London.', price='$37.00', number_of_reviews=41, review_scores_rating=4.95),
#  Row(name='WOW London Garden  Apartment', price='$137.00', number_of_reviews=115, review_scores_rating=4.83),
#  Row(name='Cosy Double Room Central Kingston SW London', price='$53.00', number_of_reviews=132, review_scores_rating=4.74),
#  Row(name='London Bridge spacious apartment', price='$129.00', number_of_reviews=82, review_scores_rating=4.93),
#  Row(name='Central flat  Bankside  London Bridge Tate Modern', price='$140.00', number_of_reviews=59, review_scores_rating=4.58),
#  Row(name='Charming loft in NW3 mews close Belsize Park tube', price='$129.00', number_of_reviews=153, review_scores_rating=4.51),
#  Row(name='Sunny and peaceful loft studio London W12', price='$66.00', number_of_reviews=67, review_scores_rating=4.94),
#  Row(name='Twin Room in Shoreditch', price='$49.00', number_of_reviews=161, review_scores_rating=4.56),
#  Row(name='Modern & bright flat near Portobello market', price='$135.00', number_of_reviews=168, review_scores_rating=4.8),
#  Row(name='Bright single room (Women only)', price='$69.00', number_of_reviews=42, review_scores_rating=4.62),
#  Row(name='Peaceful retreat  to Central London', price='$55.00', number_of_reviews=32, review_scores_rating=4.87),
#  Row(name='Single room North London', price='$38.00', number_of_reviews=239, review_scores_rating=4.82),
#  Row(name='Cosy room in shared Edwardian house', price='$38.00', number_of_reviews=134, review_scores_rating=4.73),
#  Row(name='Boutique double room with desk. Homerton, Hackney.', price='$55.00', number_of_reviews=27, review_scores_rating=4.96),
#  Row(name="'Vie de Boheme' in Central London", price='$119.00', number_of_reviews=55, review_scores_rating=4.91),
#  Row(name='Still the green side of Camden - Primrose Hill', price='$100.00', number_of_reviews=57, review_scores_rating=4.96),
#  Row(name='Double room in lovely north London flat', price='$42.00', number_of_reviews=90, review_scores_rating=4.81),
#  Row(name='Nice Room in Verdent Lane, Catford', price='$37.00', number_of_reviews=187, review_scores_rating=4.76),
#  Row(name='lovely private attic room with road and sky view', price='$41.00', number_of_reviews=314, review_scores_rating=4.95),
#  Row(name='GREAT VALUE ROOM- SAVE £££££', price='$39.00', number_of_reviews=259, review_scores_rating=4.86),
#  Row(name='B&B with en-suite shower in a friendly family home', price='$56.00', number_of_reviews=164, review_scores_rating=4.96),
#  Row(name='Large bright dbl rm w-hampstead-1', price='$55.00', number_of_reviews=38, review_scores_rating=4.76),
#  Row(name='Self-catering room in Belsize Park', price='$65.00', number_of_reviews=137, review_scores_rating=4.97),
#  Row(name='Twin Bed Room -  Acton/Shepherds Bush (SGL or DBL)', price='$59.00', number_of_reviews=437, review_scores_rating=4.92),
#  Row(name='Amazing Double Room In London', price='$69.00', number_of_reviews=69, review_scores_rating=4.72),
#  Row(name='West Kensington/Barons Court zone 2', price='$46.00', number_of_reviews=302, review_scores_rating=4.62),
#  Row(name='Double bedroom in South West London', price='$65.00', number_of_reviews=37, review_scores_rating=4.78),
#  Row(name='Picturesque Arts and Crafts Cottage', price='$27.00', number_of_reviews=98, review_scores_rating=4.67),
#  Row(name='Boutique style Bedroom with private bathroom', price='$55.00', number_of_reviews=381, review_scores_rating=4.92),
#  Row(name='Upper St. flat (Angel/Highbury& Islington)', price='$86.00', number_of_reviews=57, review_scores_rating=4.72),
#  Row(name='Private Room Close To Brick Lane', price='$32.00', number_of_reviews=120, review_scores_rating=4.83),
#  Row(name='Entire garden apartment in S London', price='$76.00', number_of_reviews=47, review_scores_rating=4.67),
#  Row(name='Blue Room in Classic London Townhouse - Zone 2', price='$90.00', number_of_reviews=22, review_scores_rating=4.62),
#  Row(name='Shoreditch/The City/Spitalfields', price='$63.00', number_of_reviews=316, review_scores_rating=4.84),
#  Row(name='Double room en suite Wanstead, park & metro London', price='$90.00', number_of_reviews=68, review_scores_rating=4.65),
#  Row(name='Explore London. Stay in 1 bed flat with Cat', price='$100.00', number_of_reviews=122, review_scores_rating=4.84),
#  Row(name='London, Zone 1, Central London Safe Private Room', price='$49.00', number_of_reviews=71, review_scores_rating=4.6),
#  Row(name='En-suite room Arsenal/Highbury', price='$87.00', number_of_reviews=97, review_scores_rating=4.75),
#  Row(name='Luxury at 22 Dalyell! Perfect Location!', price='$105.00', number_of_reviews=76, review_scores_rating=4.69),
#  Row(name='Great 2 bed flat: trendy Bermondsey', price='$131.00', number_of_reviews=75, review_scores_rating=4.84),
#  Row(name='Walk to the Olympic Stadium!', price='$121.00', number_of_reviews=84, review_scores_rating=4.74),
#  Row(name='Central-light-spacious-lovely-room', price='$57.00', number_of_reviews=37, review_scores_rating=4.95),
#  Row(name='New beautiful En Suite in south Tottenham', price='$50.00', number_of_reviews=431, review_scores_rating=4.88),
#  Row(name='Double bedroom in East London', price='$70.00', number_of_reviews=23, review_scores_rating=4.81),
#  Row(name='Comfortable single room in tranquil neighbourhood', price='$34.00', number_of_reviews=47, review_scores_rating=4.68),
#  Row(name='Private King - Room  East London', price='$33.00', number_of_reviews=107, review_scores_rating=4.73),
#  Row(name='Beautiful room in Victorian house', price='$72.00', number_of_reviews=199, review_scores_rating=4.89),
#  Row(name='Bright, spacious bedroom with own shower room', price='$100.00', number_of_reviews=450, review_scores_rating=4.95),
#  Row(name='Self-contained studio appartment with private bath', price='$70.00', number_of_reviews=196, review_scores_rating=4.76),
#  Row(name='A warm, bright, spacious, beautiful one bed flat', price='$95.00', number_of_reviews=44, review_scores_rating=4.73),
#  Row(name='Bright Nice ROOM Shoreditch Haggerston Avail', price='$43.00', number_of_reviews=58, review_scores_rating=4.62),
#  Row(name='Highgate Village, North London', price='$47.00', number_of_reviews=76, review_scores_rating=4.7),
#  Row(name='Nice spacious room', price='$37.00', number_of_reviews=32, review_scores_rating=4.75),
#  Row(name='Fabulous 1bed Victorian Flat – Home away from Home', price='$78.00', number_of_reviews=81, review_scores_rating=4.87),
#  Row(name='Newly converted loft, 2 bedrooms, bath, kitchen', price='$105.00', number_of_reviews=54, review_scores_rating=5.0),
#  Row(name='Room near Portobello & Paddington', price='$54.00', number_of_reviews=99, review_scores_rating=4.94),
#  Row(name='Outstanding location Kensington', price='$100.00', number_of_reviews=242, review_scores_rating=4.75),
#  Row(name='Well equipped spacious super king bed w/view zone2', price='$74.00', number_of_reviews=53, review_scores_rating=4.91),
#  Row(name='Lovely Double in Islington Near tube. Zone 2', price='$42.00', number_of_reviews=647, review_scores_rating=4.94),
#  Row(name='Stylish Private Retro Hackney Studio Apartment', price='$102.00', number_of_reviews=88, review_scores_rating=4.9),
#  Row(name='Excellent Shoreditch apartment - massive discount', price='$122.00', number_of_reviews=205, review_scores_rating=4.85),
#  Row(name='BEST LOCATION in Central London', price='$133.00', number_of_reviews=77, review_scores_rating=4.79),
#  Row(name='Modern stylish child friendly flat in Queens Park', price='$130.00', number_of_reviews=98, review_scores_rating=4.87),
#  Row(name='Wimbledon studio 350 m from Tennis', price='$133.00', number_of_reviews=68, review_scores_rating=4.87),
#  Row(name='Double room in beautiful Victorian home', price='$46.00', number_of_reviews=137, review_scores_rating=4.82),
#  Row(name='Notting Hill Beautiful ensuite Room', price='$113.00', number_of_reviews=24, review_scores_rating=4.91),
#  Row(name='Cosy Double bed Broadway Mkt Hackney', price='$75.00', number_of_reviews=82, review_scores_rating=4.83),
#  Row(name='Spacious Designer Garden Flat in Hackney', price='$133.00', number_of_reviews=151, review_scores_rating=4.81),
#  Row(name='Bright Double near Greenwich Park', price='$74.00', number_of_reviews=257, review_scores_rating=4.92),
#  Row(name='Studio with separate kitchen,  garden view', price='$100.00', number_of_reviews=143, review_scores_rating=4.8),
#  Row(name='Cosy twin room in lovely Victorian Home', price='$36.00', number_of_reviews=188, review_scores_rating=4.84),
#  Row(name='Great Sunny Room nr Notting Hill', price='$42.00', number_of_reviews=231, review_scores_rating=4.86),
#  Row(name='Comfortable Private Bedroom in Greenwich near 02', price='$44.00', number_of_reviews=65, review_scores_rating=4.85),
#  Row(name='Charming Notting Hill Garden Flat', price='$142.00', number_of_reviews=121, review_scores_rating=4.82),
#  Row(name='Flat in Private Historical Building', price='$115.00', number_of_reviews=90, review_scores_rating=4.51),
#  Row(name='**Lovely Double Room + Wifi**', price='$25.00', number_of_reviews=47, review_scores_rating=4.7),
#  Row(name='Cosy room, incredible location: Covent Garden/Soho', price='$146.00', number_of_reviews=410, review_scores_rating=4.7),
#  Row(name='Charming Flat  in Chelsea', price='$147.00', number_of_reviews=40, review_scores_rating=4.76),
#  Row(name='Private Room in Clerkenwell in Central London', price='$60.00', number_of_reviews=113, review_scores_rating=4.71),
#  Row(name='Sunny garden flat in Wimbledon', price='$104.00', number_of_reviews=22, review_scores_rating=5.0),
#  Row(name='Spacious Double Room Central Kingston SW London', price='$84.00', number_of_reviews=87, review_scores_rating=4.9),
#  Row(name='Twin Bedded Room in clean house', price='$44.00', number_of_reviews=274, review_scores_rating=4.77),
#  Row(name='Single Room to let in Clean House', price='$35.00', number_of_reviews=250, review_scores_rating=4.91),
#  Row(name='Stylish ensuite room  along peaceful canal', price='$65.00', number_of_reviews=43, review_scores_rating=4.83),
#  Row(name='BEAUTIFUL COSY CHELSEA FLAT', price='$44.00', number_of_reviews=78, review_scores_rating=4.76),
#  Row(name='Veggie Vegan Ensuite Near Brick Lane', price='$54.00', number_of_reviews=199, review_scores_rating=4.92),
#  Row(name='Modern Triple Studio  Zone 2 Hammersmith (5)', price='$105.00', number_of_reviews=227, review_scores_rating=4.7),
#  Row(name='Zone 2 Dbl bed 1GB WiFi Private WC Shower. Nr park', price='$76.00', number_of_reviews=339, review_scores_rating=4.9),
#  Row(name='ENTIRE Chic Apartment in Central London, sleeps 5.', price='$98.00', number_of_reviews=707, review_scores_rating=4.86),
#  Row(name='RIVERSIDE Cosy SECURE double rm-hotel style shower', price='$57.00', number_of_reviews=46, review_scores_rating=4.74),
#  Row(name='short to medium term airbnb singles/c Lon/Hydepark', price='$100.00', number_of_reviews=57, review_scores_rating=4.65),
#  Row(name="SUPER XL ATTIC | Piccadilly Line | 16m KING'S X", price='$36.00', number_of_reviews=118, review_scores_rating=4.67),
#  Row(name='Room in Designer House Notting Hill', price='$86.00', number_of_reviews=499, review_scores_rating=4.84),
#  Row(name='Spacious Double Bedrooms in Fulham/Hammersmith', price='$78.00', number_of_reviews=154, review_scores_rating=4.87),
#  Row(name='3 Double Rooms by River in Fulham shared house', price='$78.00', number_of_reviews=216, review_scores_rating=4.88),
#  Row(name='Large bedroom in a family house', price='$55.00', number_of_reviews=49, review_scores_rating=4.88),
#  Row(name='Double room Camden designer flat with own bathroom', price='$94.00', number_of_reviews=157, review_scores_rating=4.88),
#  Row(name='London room - 15 mins to Eurostar', price='$45.00', number_of_reviews=178, review_scores_rating=4.7),
#  Row(name='Spacious 2 bed flat Ealing sleeps one family of 5', price='$149.00', number_of_reviews=318, review_scores_rating=4.8),
#  Row(name='Notting Hill Garden Studio Room +Cats', price='$75.00', number_of_reviews=135, review_scores_rating=4.88),
#  Row(name='Come enjoy our hospitality', price='$48.00', number_of_reviews=149, review_scores_rating=4.88),
#  Row(name='West Kensington central London', price='$49.00', number_of_reviews=337, review_scores_rating=4.56),
#  Row(name='Fulham, Earls Crt.Dble  rm-£65 single/£95 2 guests', price='$65.00', number_of_reviews=133, review_scores_rating=4.85),
#  Row(name='LAST MINUTE - SINGLE ROOM', price='$33.00', number_of_reviews=182, review_scores_rating=4.88),
#  Row(name='Large private flat close to central London', price='$113.00', number_of_reviews=304, review_scores_rating=4.86),
#  Row(name='Single Cosy Room+FastWifi No snorers/3 mins shop', price='$41.00', number_of_reviews=94, review_scores_rating=4.84),
#  Row(name='Beautiful room in lovely home.', price='$77.00', number_of_reviews=74, review_scores_rating=4.97),
#  Row(name='Beautiful En-suite Room in London', price='$60.00', number_of_reviews=74, review_scores_rating=4.85),
#  Row(name='Lovely Knightsbridge Flat - central, quiet, garden', price='$143.00', number_of_reviews=83, review_scores_rating=4.55),
#  Row(name='En-Suite, Big, Sunny Double', price='$58.00', number_of_reviews=49, review_scores_rating=4.92),
#  Row(name='Your London home away from home', price='$131.00', number_of_reviews=42, review_scores_rating=4.55),
#  Row(name='Lovely room suitable for lady only', price='$27.00', number_of_reviews=51, review_scores_rating=4.72),
#  Row(name='Calm Luxe Hotel Styled 2 Bed in Vibrant Brixton', price='$132.00', number_of_reviews=36, review_scores_rating=4.6),
#  Row(name='Fabulous flat for foodies and city explorers', price='$96.00', number_of_reviews=307, review_scores_rating=4.74),
#  Row(name='Airy Loft Studio with en-suite bathroom', price='$86.00', number_of_reviews=128, review_scores_rating=4.84),
#  Row(name='Single room in large house Gospel Oak/Tufnell Park', price='$55.00', number_of_reviews=53, review_scores_rating=4.87),
#  Row(name='Stunning Art Deco flat East London', price='$121.00', number_of_reviews=43, review_scores_rating=4.56),
#  Row(name='Well reviewed in quiet residential area of London', price='$149.00', number_of_reviews=223, review_scores_rating=4.88),
#  Row(name='ZONE 1 - Spacious 1 bed Flat Close to amenities', price='$127.00', number_of_reviews=95, review_scores_rating=4.54),
#  Row(name='Gorgeous 1st floor apartment - 1 min from station', price='$134.00', number_of_reviews=113, review_scores_rating=4.65),
#  Row(name='BEAUTIFUL STUDIO SKYLINES  wifi WHOLE FLAT', price='$100.00', number_of_reviews=66, review_scores_rating=4.51),
#  Row(name='BALCONY/OVERLOOKING RUGBY GROUND WI FI  WHOLE FLAT', price='$99.00', number_of_reviews=82, review_scores_rating=4.54),
#  Row(name='private dblbedroom in Ham/ Richmond', price='$60.00', number_of_reviews=23, review_scores_rating=4.83),
#  Row(name='Private Bath Family room - London Bridge 1 stop', price='$75.00', number_of_reviews=236, review_scores_rating=4.75),
#  Row(name='Dble Room+Wi-Fi-Arsenal/Clissold park/North London', price='$63.00', number_of_reviews=56, review_scores_rating=4.91),
#  Row(name='ROOM EN-SUITE BATHROOM Heathrow & Film studios', price='$45.00', number_of_reviews=39, review_scores_rating=4.97),
#  Row(name='London house with en-suite rooms 5', price='$55.00', number_of_reviews=303, review_scores_rating=4.83),
#  Row(name='Bright London spaceious overlooking rugby ground', price='$80.00', number_of_reviews=77, review_scores_rating=4.54),
#  Row(name='Cosy Medium sized room in Shepherds Bush', price='$53.00', number_of_reviews=228, review_scores_rating=4.77),
#  Row(name='Cosy double', price='$75.00', number_of_reviews=146, review_scores_rating=4.73),
#  Row(name='Modern Triple Studio Zone 2 Hammersmith (10)', price='$90.00', number_of_reviews=243, review_scores_rating=4.73),
#  Row(name='Beautiful one bed in the heart of Notting Hill', price='$104.00', number_of_reviews=188, review_scores_rating=4.76),
#  Row(name='Super Fast Transport, Superior Boutique Comfort', price='$45.00', number_of_reviews=227, review_scores_rating=4.87),
#  Row(name='Beautiful warehouse-style room in Hackney.', price='$48.00', number_of_reviews=105, review_scores_rating=4.82),
#  Row(name='Contemporary & Bright Flat Fulham', price='$136.00', number_of_reviews=71, review_scores_rating=4.58),
#  Row(name='Light, bright room North London', price='$32.00', number_of_reviews=32, review_scores_rating=4.9),
#  Row(name='Double ensuite+terrace', price='$95.00', number_of_reviews=46, review_scores_rating=4.78),
#  Row(name='Small, cosy, garden DOUBLE room with bathroom', price='$53.00', number_of_reviews=314, review_scores_rating=4.72),
#  Row(name='Double Room Close to Tube Quiet Rd', price='$68.00', number_of_reviews=110, review_scores_rating=4.88),
#  Row(name='Cosy Shoreditch Studio in ArtDecoCinema Conversion', price='$111.00', number_of_reviews=161, review_scores_rating=4.85),
#  Row(name='Beautiful Non Smoking London Home', price='$135.00', number_of_reviews=33, review_scores_rating=4.64),
#  Row(name='Shoreditch Central/East London Lively Zone 1', price='$50.00', number_of_reviews=122, review_scores_rating=4.81),
#  Row(name='Space in well equipped London pad', price='$50.00', number_of_reviews=219, review_scores_rating=4.67),
#  Row(name='Lovely Modern Quiet En-suite Studio Room', price='$63.00', number_of_reviews=295, review_scores_rating=4.82),
#  Row(name='Waterloo Heights Deluxe', price='$54.00', number_of_reviews=102, review_scores_rating=4.53),
#  Row(name='Stepney House - affordable luxury', price='$90.00', number_of_reviews=156, review_scores_rating=4.97),
#  Row(name='Quiet single room in Fulham', price='$51.00', number_of_reviews=401, review_scores_rating=4.81),
#  Row(name='Double Room close to Camberwell College and Kings', price='$44.00', number_of_reviews=87, review_scores_rating=4.82),
#  Row(name='Sofa bed in the living room looks out to garden', price='$27.00', number_of_reviews=314, review_scores_rating=4.73),
#  Row(name='Stepney House 2 - affordable Luxury', price='$87.00', number_of_reviews=94, review_scores_rating=4.97),
#  Row(name='Spacious Double in shared home close to Heathrow', price='$61.00', number_of_reviews=46, review_scores_rating=4.56),
#  Row(name='Wimbledon Village Sleeps 3 Cute Cottage', price='$116.00', number_of_reviews=212, review_scores_rating=4.93),
#  Row(name='Brilliantly Located Apartment', price='$77.00', number_of_reviews=79, review_scores_rating=4.54),
#  Row(name='Richmond on Thames Huge quiet private  Studio!', price='$135.00', number_of_reviews=117, review_scores_rating=4.85),
#  Row(name='Single Room+Fast Wi-Fi/No snorers', price='$33.00', number_of_reviews=59, review_scores_rating=4.83),
#  Row(name='Gorgeous 1 Bed garden flat, Camden !!33% OFF!!', price='$129.00', number_of_reviews=166, review_scores_rating=4.91),
#  Row(name='Double with bathroom in LGBT friendly home', price='$85.00', number_of_reviews=272, review_scores_rating=4.98),
#  Row(name='Twin room, Close to Underground Quiet Road', price='$68.00', number_of_reviews=143, review_scores_rating=4.91),
#  Row(name='Single Room Close To Tube Quiet Rd', price='$44.00', number_of_reviews=132, review_scores_rating=4.93),
#  Row(name='London house with en-suite rooms 2', price='$55.00', number_of_reviews=350, review_scores_rating=4.85),
#  Row(name='London house with en-suite rooms 1', price='$55.00', number_of_reviews=256, review_scores_rating=4.82),
#  Row(name='London house with en-suite rooms 4', price='$55.00', number_of_reviews=333, review_scores_rating=4.89),
#  Row(name='Large and spacious  family bedroom', price='$43.00', number_of_reviews=160, review_scores_rating=4.69),
#  Row(name='Nice single room with small double bed', price='$38.00', number_of_reviews=187, review_scores_rating=4.83),
#  Row(name='Private Room in Central London', price='$60.00', number_of_reviews=87, review_scores_rating=4.55),
#  Row(name='Beautiful location cosy Studio flat', price='$80.00', number_of_reviews=122, review_scores_rating=4.55),
#  Row(name='Central, Camden, Hampstead Dbl Room, Bath & Lounge', price='$90.00', number_of_reviews=652, review_scores_rating=4.92),
#  Row(name='Charming 1 bedroom house with 2 bathrooms', price='$110.00', number_of_reviews=128, review_scores_rating=4.52),
#  Row(name='Cosy apartment in Covent Garden', price='$147.00', number_of_reviews=153, review_scores_rating=4.97),
#  Row(name='Gorgeous family riverside flat', price='$111.00', number_of_reviews=23, review_scores_rating=4.87),
#  Row(name='Charming room in Kings Cross', price='$72.00', number_of_reviews=229, review_scores_rating=4.92),
#  Row(name='double garden bedroom with ensuite', price='$70.00', number_of_reviews=188, review_scores_rating=4.92),
#  Row(name='Crayford - Camden Islington', price='$124.00', number_of_reviews=24, review_scores_rating=4.67),
#  Row(name='1BR Apartment in Zone 2 South London_Georgeous!', price='$99.00', number_of_reviews=41, review_scores_rating=4.9),
#  Row(name='Large double room with private en-suite bathroom', price='$95.00', number_of_reviews=106, review_scores_rating=4.65),
#  Row(name='Penthouse Room with Views over Park, near Station', price='$54.00', number_of_reviews=313, review_scores_rating=4.87),
#  Row(name='Private Room, Central London – Stylish & Easy', price='$59.00', number_of_reviews=278, review_scores_rating=4.81),
#  Row(name='Sunny, spacious oasis in  the heart of Dalston', price='$51.00', number_of_reviews=246, review_scores_rating=4.66),
#  Row(name='Beautiful Double Room: downstairs', price='$50.00', number_of_reviews=42, review_scores_rating=4.95),
#  Row(name='1BD apartment in heart of London W1', price='$119.00', number_of_reviews=93, review_scores_rating=4.61),
#  Row(name='5* Stylish, spacious room.   (Zone 3 West Norwood)', price='$44.00', number_of_reviews=161, review_scores_rating=4.94),
#  Row(name='Double room  private bathroom  LGBT friendly home', price='$75.00', number_of_reviews=335, review_scores_rating=4.96),
#  Row(name='Large double room with private toilet/shower', price='$113.00', number_of_reviews=120, review_scores_rating=4.8),
#  Row(name='Lovely, Sunny, Quiet Double', price='$40.00', number_of_reviews=42, review_scores_rating=4.9),
#  Row(name='Room with a view', price='$59.00', number_of_reviews=211, review_scores_rating=4.93),
#  Row(name='SW London-large modern flat. Great transport Links', price='$132.00', number_of_reviews=236, review_scores_rating=4.87),
#  Row(name='Double room (women or couples only)', price='$91.00', number_of_reviews=35, review_scores_rating=4.68),
#  Row(name='Light-filled room with own amenities.', price='$81.00', number_of_reviews=47, review_scores_rating=5.0),
#  Row(name='Arts and Crafts house, good transport', price='$58.00', number_of_reviews=31, review_scores_rating=4.94),
#  Row(name='Boutique bijoux garden flat in vibrant Oval', price='$72.00', number_of_reviews=295, review_scores_rating=4.79),
#  Row(name='1BD apartment in Trendy Dalston', price='$68.00', number_of_reviews=129, review_scores_rating=4.61),
#  Row(name='Modern apt in Trendy Dalston', price='$73.00', number_of_reviews=132, review_scores_rating=4.6),
#  Row(name='Stunning Flat with Private Garden', price='$67.00', number_of_reviews=293, review_scores_rating=4.78),
#  Row(name='Private room in London apartment', price='$43.00', number_of_reviews=41, review_scores_rating=4.93),
#  Row(name='Lovely Family friendly Rooms (no 4 and 5)', price='$143.00', number_of_reviews=119, review_scores_rating=4.83),
#  Row(name='Whole private self-contained studio @ Clapton Pond', price='$82.00', number_of_reviews=179, review_scores_rating=4.81),
#  Row(name='Double Room, OWN Bathroom, Zone 1!', price='$92.00', number_of_reviews=48, review_scores_rating=5.0),
#  Row(name='Bethnal Green, Period Mansion Block.', price='$65.00', number_of_reviews=193, review_scores_rating=4.87),
#  Row(name='Peaceful.Garden.Notting Hill', price='$51.00', number_of_reviews=108, review_scores_rating=4.87),
#  Row(name='Bright beautiful trendy London APT', price='$98.00', number_of_reviews=211, review_scores_rating=4.86),
#  Row(name='1 Bed Flat off Kentish Town High St', price='$110.00', number_of_reviews=254, review_scores_rating=4.93),
#  Row(name='Private Entrance En-Suite in beautiful Hampstead', price='$132.00', number_of_reviews=82, review_scores_rating=4.84),
#  Row(name='Relaxing Georgian house in London', price='$110.00', number_of_reviews=128, review_scores_rating=4.96),
#  Row(name='Sunny Single Room Finsbury Park', price='$61.00', number_of_reviews=97, review_scores_rating=4.57),
#  Row(name='South facing charming vibrant/cool Clapton/Hackney', price='$58.00', number_of_reviews=63, review_scores_rating=4.73),
#  Row(name='Modern room with an italian touch', price='$80.00', number_of_reviews=43, review_scores_rating=4.93),
#  Row(name='Comfortable Private Room, London, Redbridge,Zone4', price='$42.00', number_of_reviews=58, review_scores_rating=4.81),
#  Row(name='A private room for two in London in Zone 2', price='$55.00', number_of_reviews=47, review_scores_rating=4.96),
#  Row(name='Smart Medium Sized Room', price='$53.00', number_of_reviews=258, review_scores_rating=4.86),
#  Row(name='Dble room very near train st - no cleaning fee', price='$57.00', number_of_reviews=303, review_scores_rating=4.96),
#  Row(name='Hip, homely, and spacious flat in Hither Green', price='$111.00', number_of_reviews=23, review_scores_rating=4.74),
#  Row(name="Cosy double room, children's room and roof garden", price='$82.00', number_of_reviews=153, review_scores_rating=4.74),
#  Row(name='Cosy Stylish Flat by Canal in East London E2', price='$105.00', number_of_reviews=50, review_scores_rating=4.8),
#  Row(name='Gorgeous 1 bed flat, London Fields', price='$140.00', number_of_reviews=35, review_scores_rating=4.8),
#  Row(name='Beautiful Double Room (R2)', price='$48.00', number_of_reviews=122, review_scores_rating=4.54),
#  Row(name='London house with en-suite rooms 3', price='$55.00', number_of_reviews=292, review_scores_rating=4.86),
#  Row(name='Lovely self contained private studio room in W12', price='$95.00', number_of_reviews=22, review_scores_rating=4.82),
#  Row(name='Chelsea Georgian terraced house with room', price='$73.00', number_of_reviews=63, review_scores_rating=4.78),
#  Row(name='Chic Double En-Suite in Heart of West End', price='$58.00', number_of_reviews=180, review_scores_rating=4.83),
#  Row(name='room in central greenwich london', price='$43.00', number_of_reviews=102, review_scores_rating=4.52),
#  Row(name='Cozy Fitzrovia studio on cobbled st', price='$127.00', number_of_reviews=381, review_scores_rating=4.66),
#  Row(name='Large bright dbl rm w-hampstead-2', price='$55.00', number_of_reviews=37, review_scores_rating=4.89),
#  Row(name='Comfortable, convenient flat in heart of Dalston', price='$145.00', number_of_reviews=71, review_scores_rating=4.7),
#  Row(name='West End - Third - Top floor - Superior apartment', price='$127.00', number_of_reviews=345, review_scores_rating=4.85),
#  Row(name='Central London Large Studio Flat', price='$114.00', number_of_reviews=289, review_scores_rating=4.89),
#  Row(name='Sunny flat with balcony in Battersea', price='$96.00', number_of_reviews=77, review_scores_rating=4.65),
#  Row(name='Twin bed room with en suite SW19', price='$65.00', number_of_reviews=195, review_scores_rating=4.73),
#  Row(name='Double room/ensuite shower, London', price='$72.00', number_of_reviews=34, review_scores_rating=4.88),
#  Row(name='Central London Superior Apartment second floor', price='$132.00', number_of_reviews=322, review_scores_rating=4.91),
#  Row(name='Beautiful double bedroom', price='$45.00', number_of_reviews=132, review_scores_rating=4.77),
#  Row(name='Spacious room in Central London', price='$40.00', number_of_reviews=161, review_scores_rating=4.88),
#  Row(name='2 bedroom spacious garden flat (full use of flat)', price='$149.00', number_of_reviews=78, review_scores_rating=4.87),
#  Row(name='Cosy & Stylish Double Room in Sunny Chiswick 1', price='$55.00', number_of_reviews=122, review_scores_rating=4.83),
#  Row(name='Double Room in Central Dalston Penthouse', price='$50.00', number_of_reviews=51, review_scores_rating=4.9),
#  Row(name='Bedroo with own toilet/Central', price='$68.00', number_of_reviews=123, review_scores_rating=4.77),
#  Row(name='beautiful  flat for rent N London', price='$121.00', number_of_reviews=98, review_scores_rating=4.65),
#  Row(name='beautiful maisonette for rent', price='$100.00', number_of_reviews=49, review_scores_rating=4.79),
#  Row(name='Double bedroom in amazing flat', price='$62.00', number_of_reviews=45, review_scores_rating=4.96),
#  Row(name='Peaceful Double Room- Hackney', price='$40.00', number_of_reviews=173, review_scores_rating=4.88),
#  Row(name='Super Central! Paddington, Marylebone (+ quiet!)', price='$116.00', number_of_reviews=457, review_scores_rating=4.64),
#  Row(name='Cosy Room in Leafy Chiswick (R1)', price='$42.00', number_of_reviews=161, review_scores_rating=4.54),
#  Row(name='LONDON EYE VIEWS', price='$140.00', number_of_reviews=120, review_scores_rating=4.84),
#  Row(name='London for Less', price='$57.00', number_of_reviews=34, review_scores_rating=4.68),
#  Row(name='Prime Location! Stunning studio NW3', price='$147.00', number_of_reviews=154, review_scores_rating=4.9),
#  Row(name='Large Super Clean Private Studio@Highbury', price='$96.00', number_of_reviews=176, review_scores_rating=4.78),
#  Row(name='Double room in spacious flat in trendy area', price='$99.00', number_of_reviews=37, review_scores_rating=4.78),
#  Row(name='Private suite in beautiful home', price='$102.00', number_of_reviews=316, review_scores_rating=4.97),
#  Row(name='Room  in Highgate Village', price='$43.00', number_of_reviews=54, review_scores_rating=4.76),
#  Row(name='Studio in a 2bd house', price='$99.00', number_of_reviews=198, review_scores_rating=4.89),
#  Row(name='Lovely Spacious 2 bed Quiet Flat-Central- Kings X', price='$146.00', number_of_reviews=131, review_scores_rating=4.82),
#  Row(name='Bright and airy double bedroom, Hyde Park', price='$108.00', number_of_reviews=323, review_scores_rating=4.82),
#  Row(name='spacious double bedroom', price='$56.00', number_of_reviews=78, review_scores_rating=4.86),
#  Row(name='Bright topfloor flat with off st parking & garden', price='$128.00', number_of_reviews=84, review_scores_rating=4.94),
#  Row(name='Lovely two bed flat, St. Johns Wood', price='$145.00', number_of_reviews=130, review_scores_rating=4.98),
#  Row(name='Lovely bright double garden room in Victorian home', price='$40.00', number_of_reviews=94, review_scores_rating=4.91),
#  Row(name="Artist's house - single room", price='$48.00', number_of_reviews=21, review_scores_rating=5.0),
#  Row(name='Lovely room , ensuite, SW London (Teddington)', price='$110.00', number_of_reviews=23, review_scores_rating=4.96),
#  Row(name="COSY XL | Piccadilly Line | 16 m to KING'S CROSS", price='$35.00', number_of_reviews=92, review_scores_rating=4.55),
# ...
#  Row(name='Lovely Ensuite Canalside  Dbl Room', price='$69.00', number_of_reviews=102, review_scores_rating=4.88),
#  Row(name='COSY SPACE | Piccadilly Line | 20 m Central London', price='$34.00', number_of_reviews=152, review_scores_rating=4.67),
#  Row(name='Double Room in loft apartment Ten min to west end', price='$58.00', number_of_reviews=31, review_scores_rating=4.77),
#  Row(name='Double Bedroom in SW11.', price='$58.00', number_of_reviews=96, review_scores_rating=4.93),
#  Row(name='En-suite loft room in nice area', price='$64.00', number_of_reviews=267, review_scores_rating=4.78),
#  Row(name='Sunny Studio 1 with Lovely Patio.', price='$60.00', number_of_reviews=177, review_scores_rating=4.67),
#  Row(name='Double room in the heart of Brixton', price='$68.00', number_of_reviews=37, review_scores_rating=4.68),
#  Row(name='Cozy double bedroom in Lewisham', price='$45.00', number_of_reviews=196, review_scores_rating=4.79),
#  Row(name='Stylish 1 bedroom new build flat', price='$121.00', number_of_reviews=41, review_scores_rating=4.85),
#  Row(name='Beautiful 1 Bedroom Flat East LDN', price='$147.00', number_of_reviews=52, review_scores_rating=4.69),
#  Row(name='Boutique Mansion North London Arty Quirky Cosy', price='$75.00', number_of_reviews=55, review_scores_rating=4.89),
#  Row(name='Lovely attic room in London', price='$50.00', number_of_reviews=183, review_scores_rating=4.85),
#  Row(name='A beautiful flat in West Kensington without a Host', price='$117.00', number_of_reviews=54, review_scores_rating=4.61),
#  Row(name='Studio Apartment with En Suite', price='$98.00', number_of_reviews=55, review_scores_rating=4.89),
#  Row(name='Beautiful studio loft room ensuite', price='$48.00', number_of_reviews=791, review_scores_rating=4.81),
#  Row(name='Studio 8- Luxury for less, Delightfully Decadent', price='$57.00', number_of_reviews=269, review_scores_rating=4.9),
#  Row(name='Charming rooms in period house with breakfast', price='$100.00', number_of_reviews=163, review_scores_rating=5.0),
#  Row(name='Double Room 5mins from Canary Wharf.', price='$74.00', number_of_reviews=70, review_scores_rating=4.79),
#  Row(name='HACKNEY - 1 bedroom flat with gym and concierge', price='$124.00', number_of_reviews=60, review_scores_rating=4.93),
#  Row(name='Paddington/Bayswater W2 Private room, private bath', price='$82.00', number_of_reviews=125, review_scores_rating=4.91),
#  Row(name='Studio 7-London City style with Direct Train Links', price='$76.00', number_of_reviews=364, review_scores_rating=4.88),
#  Row(name='Micro Studio, 2 mins walk to “Angel” (Zone 1 Tube)', price='$59.00', number_of_reviews=212, review_scores_rating=4.81),
#  Row(name='Single Neat room Large Boutique Mansion Gardens +', price='$50.00', number_of_reviews=101, review_scores_rating=4.89),
#  Row(name='Elegant Room for Single Traveller or Couple', price='$54.00', number_of_reviews=130, review_scores_rating=4.89),
#  Row(name='My spare room is for rent', price='$45.00', number_of_reviews=108, review_scores_rating=4.9),
#  Row(name='**Relaxing Experience - Central Location**', price='$94.00', number_of_reviews=367, review_scores_rating=4.89),
#  Row(name='Period Townhouse with own garden', price='$60.00', number_of_reviews=93, review_scores_rating=4.91),
#  Row(name='**Great Experience - Central Location**', price='$85.00', number_of_reviews=597, review_scores_rating=4.91),
#  Row(name='Deluxe Tower Bridge Apartment', price='$130.00', number_of_reviews=65, review_scores_rating=4.69),
#  Row(name='Modern twin bed/super king ensuite bath/shower', price='$91.00', number_of_reviews=87, review_scores_rating=4.93),
#  Row(name='Private Bedroom, lounge, bathroom beautiful home.', price='$116.00', number_of_reviews=199, review_scores_rating=4.93),
#  Row(name='Garden flat near Finsbury Park', price='$119.00', number_of_reviews=75, review_scores_rating=4.91),
#  Row(name='Tooting Cute and Cosy En Suite', price='$48.00', number_of_reviews=57, review_scores_rating=4.79),
#  Row(name='Tooting Spacious Brit Double London', price='$41.00', number_of_reviews=81, review_scores_rating=4.65),
#  Row(name='Tooting Cute Clean and Cosy', price='$47.00', number_of_reviews=77, review_scores_rating=4.61),
#  Row(name='Tooting Primo Room', price='$46.00', number_of_reviews=78, review_scores_rating=4.71),
#  Row(name='Entire flat, 7 min from the heart of London', price='$67.00', number_of_reviews=36, review_scores_rating=4.83),
#  Row(name='Beautiful flat in a great location', price='$121.00', number_of_reviews=88, review_scores_rating=4.94),
#  Row(name='Double room in bermondsey London', price='$75.00', number_of_reviews=26, review_scores_rating=4.58),
#  Row(name='London Peckham, Females only, Modern & Bright room', price='$51.00', number_of_reviews=245, review_scores_rating=4.95),
#  Row(name='Bright room in pretty garden flat', price='$55.00', number_of_reviews=253, review_scores_rating=4.9),
#  Row(name='Self contained studio near Camden', price='$95.00', number_of_reviews=337, review_scores_rating=4.93),
#  Row(name='Room in Dalston Bible Factory', price='$63.00', number_of_reviews=373, review_scores_rating=4.89),
#  Row(name='A little gem in the heart of London, Holborn', price='$136.00', number_of_reviews=53, review_scores_rating=4.96),
#  Row(name='Large room, Hackney. Near cafes, eateries, nature', price='$55.00', number_of_reviews=46, review_scores_rating=4.57),
#  Row(name='Arty double room in quiet,safe area of N21', price='$40.00', number_of_reviews=110, review_scores_rating=4.96),
#  Row(name='Elegant Kingsize in Kensal with own Kitch/Bathroom', price='$115.00', number_of_reviews=262, review_scores_rating=4.97),
#  Row(name='Kingston Double ~ Private Bathroom ~ just for YOU', price='$58.00', number_of_reviews=162, review_scores_rating=4.99),
#  Row(name='Beautiful Sun Shiny Flat in Camden', price='$51.00', number_of_reviews=59, review_scores_rating=4.9),
#  Row(name='Bright Room 7mins to London Bridge', price='$57.00', number_of_reviews=182, review_scores_rating=4.75),
#  Row(name='No sharing Private Apartment, Archves  Kew Gardens', price='$89.00', number_of_reviews=42, review_scores_rating=4.71),
#  Row(name='TRENDY ART FLAT - best Shoreditch location', price='$117.00', number_of_reviews=83, review_scores_rating=4.84),
#  Row(name='Sunlit Loft Room in Victorian Home by Richmond Park', price='$60.00', number_of_reviews=335, review_scores_rating=4.95),
#  Row(name='Lovely bedroom in bright, sunny flat in London', price='$36.00', number_of_reviews=36, review_scores_rating=4.94),
#  Row(name='Charming one-bedroom apartment in South Kensington', price='$105.00', number_of_reviews=24, review_scores_rating=4.75),
#  Row(name='Beautiful flat in central Wimbledon', price='$105.00', number_of_reviews=73, review_scores_rating=4.71),
#  Row(name='Close to All England Tennis Wimbledon - Chinese Rm', price='$86.00', number_of_reviews=97, review_scores_rating=4.97),
#  Row(name='Bright double 7min to London Bridge', price='$53.00', number_of_reviews=178, review_scores_rating=4.8),
#  Row(name='Queen Victoria Era Home For 3 in Abbeville Village', price='$58.00', number_of_reviews=294, review_scores_rating=4.73),
#  Row(name='Beautiful Architect home+garden Dalston Hackney', price='$99.00', number_of_reviews=23, review_scores_rating=4.96),
#  Row(name='(6) Modern Spacious Lux Flat in Central London', price='$55.00', number_of_reviews=53, review_scores_rating=4.87),
#  Row(name='Single Room South West London SW17', price='$46.00', number_of_reviews=109, review_scores_rating=4.9),
#  Row(name='Private room', price='$100.00', number_of_reviews=212, review_scores_rating=4.94),
#  Row(name='Stunning flat with garden in West London', price='$125.00', number_of_reviews=47, review_scores_rating=4.53),
#  Row(name='The Vintage Room in Kew Gardens', price='$135.00', number_of_reviews=85, review_scores_rating=4.8),
#  Row(name='Large private room and bathroom in quiet NW2 house', price='$90.00', number_of_reviews=97, review_scores_rating=4.87),
#  Row(name='Bright Flat in Herne Hill with great transport', price='$95.00', number_of_reviews=125, review_scores_rating=4.77),
#  Row(name='Stunning Victorian flat w/. parking', price='$94.00', number_of_reviews=79, review_scores_rating=4.87),
#  Row(name='Lovely, sunny double room in friendly family home', price='$45.00', number_of_reviews=281, review_scores_rating=4.97),
#  Row(name='Single Room, House, Private Carpark', price='$63.00', number_of_reviews=152, review_scores_rating=4.95),
#  Row(name='96TR | En-Suite Bedroom with Bathroom', price='$38.00', number_of_reviews=386, review_scores_rating=4.75),
#  Row(name='The Captain Cook Double Room in Boutique Hotel R3', price='$104.00', number_of_reviews=92, review_scores_rating=4.79),
#  Row(name='The Captain Cook Double Room in Boutique Hotel R8', price='$99.00', number_of_reviews=49, review_scores_rating=4.73),
#  Row(name='Riverside,Large Private Double room with ensuite', price='$93.00', number_of_reviews=379, review_scores_rating=4.92),
#  Row(name='Bright,Clean, Modern Central London 1st floor Flat', price='$148.00', number_of_reviews=121, review_scores_rating=4.54),
#  Row(name='(Entire Flat)Fabulous Central London Modern Studio', price='$145.00', number_of_reviews=153, review_scores_rating=4.68),
#  Row(name='Private, clean, comfortable double bed & en-suite', price='$63.00', number_of_reviews=70, review_scores_rating=4.91),
#  Row(name='Double room for single person.', price='$44.00', number_of_reviews=333, review_scores_rating=4.84),
#  Row(name='The Cozy River Side Place for your days in london', price='$100.00', number_of_reviews=127, review_scores_rating=4.6),
#  Row(name='Big double with desk & free gym access', price='$60.00', number_of_reviews=21, review_scores_rating=4.9),
#  Row(name='Double Room, Hackney, East London -Vaccinated Host', price='$35.00', number_of_reviews=164, review_scores_rating=4.78),
#  Row(name='Positively Pristine 1 Bed Period Flat, Crouch End', price='$98.00', number_of_reviews=98, review_scores_rating=4.9),
#  Row(name='Highbury Garden House - Queen Room', price='$99.00', number_of_reviews=238, review_scores_rating=4.85),
#  Row(name='Sunny and quiet house in East Dulwich', price='$115.00', number_of_reviews=65, review_scores_rating=4.98),
#  Row(name='Double Room in Riverside Triplex', price='$115.00', number_of_reviews=22, review_scores_rating=5.0),
#  Row(name='Peaceful room by park on fast Underground line', price='$34.00', number_of_reviews=141, review_scores_rating=4.86),
#  Row(name='A large bedroom to rent for 1 person.', price='$38.00', number_of_reviews=77, review_scores_rating=4.82),
#  Row(name='Stylish apartment in trendy Dalston', price='$115.00', number_of_reviews=42, review_scores_rating=4.9),
#  Row(name='Private Room in Period House, Trendy East London', price='$69.00', number_of_reviews=31, review_scores_rating=4.97),
#  Row(name='Great double room with Free Wi Fi!!', price='$43.00', number_of_reviews=93, review_scores_rating=4.85),
#  Row(name='Double room near Tottenham Stadium and Drumsheds', price='$68.00', number_of_reviews=62, review_scores_rating=4.98),
#  Row(name='Stylish bright 1 bed room apartment', price='$136.00', number_of_reviews=262, review_scores_rating=4.91),
#  Row(name='Comfortable loft room  with ensuite shower room.', price='$44.00', number_of_reviews=123, review_scores_rating=4.98),
#  Row(name='Bright and sunny double room.', price='$43.00', number_of_reviews=97, review_scores_rating=4.94),
#  Row(name='Twin Room in Quiet Location', price='$34.00', number_of_reviews=31, review_scores_rating=4.87),
#  Row(name='Spacious Room Prime Location next to Hyde Park', price='$91.00', number_of_reviews=76, review_scores_rating=4.66),
#  Row(name='Charming London apartment with rooftop terrace', price='$146.00', number_of_reviews=102, review_scores_rating=4.89),
#  Row(name='Islington Arsenal Zone 2, nice area, 2 mins tube', price='$50.00', number_of_reviews=613, review_scores_rating=4.84),
#  Row(name='Double Bedroom in Lovely 2 Bed Flat', price='$34.00', number_of_reviews=305, review_scores_rating=4.88),
#  Row(name='Big and bright 2 x double bedroom flat in Highgate', price='$149.00', number_of_reviews=30, review_scores_rating=4.7),
#  Row(name='Single room/Student Accommodation', price='$23.00', number_of_reviews=67, review_scores_rating=4.99),
#  Row(name='Sunny Kingsize Bed/En-suite Zone2 Clapham Common', price='$78.00', number_of_reviews=87, review_scores_rating=4.79),
#  Row(name='Cosy double room, 15 - 22 mins to centre', price='$33.00', number_of_reviews=91, review_scores_rating=4.88),
#  Row(name='Bedroom for One', price='$44.00', number_of_reviews=181, review_scores_rating=4.81),
#  Row(name='Double Room with private shower room  in Harrow', price='$38.00', number_of_reviews=40, review_scores_rating=4.8),
#  Row(name='Luxury Double Room + Private Bath,Modern Apartment', price='$65.00', number_of_reviews=129, review_scores_rating=4.95),
#  Row(name='Near Westminster, Flat in Vauxhall.', price='$114.00', number_of_reviews=198, review_scores_rating=4.51),
#  Row(name='Tranquil Double Bedroom Wimbledon', price='$77.00', number_of_reviews=24, review_scores_rating=4.79),
#  Row(name='Quiet, laid back opposite a field', price='$39.00', number_of_reviews=174, review_scores_rating=4.83),
#  Row(name='comfortable and clean double room', price='$45.00', number_of_reviews=79, review_scores_rating=4.82),
#  Row(name='Room in mews flat - West Hampstead', price='$72.00', number_of_reviews=24, review_scores_rating=4.83),
#  Row(name='Comfy Double bed room', price='$35.00', number_of_reviews=28, review_scores_rating=4.75),
#  Row(name='*Female Only* Cosy double bedroom great location', price='$38.00', number_of_reviews=143, review_scores_rating=4.73),
#  Row(name='Double bed for a single person', price='$29.00', number_of_reviews=37, review_scores_rating=4.73),
#  Row(name='Modern and spacious apartment', price='$100.00', number_of_reviews=110, review_scores_rating=4.74),
#  Row(name='Central London Apartment - Female Guests Only', price='$77.00', number_of_reviews=136, review_scores_rating=4.9),
#  Row(name='Cozy 1BD next to Canary Wharf', price='$54.00', number_of_reviews=65, review_scores_rating=4.88),
#  Row(name='Lovely double room in a house in W5  £60/night', price='$60.00', number_of_reviews=141, review_scores_rating=4.92),
#  Row(name='Balcony on a Tree Lined Street Shoreditch London', price='$144.00', number_of_reviews=73, review_scores_rating=4.66),
#  Row(name='Bedroom/study with your own private bathroom', price='$78.00', number_of_reviews=42, review_scores_rating=4.98),
#  Row(name='Single Room.Shared house.30 min to Center. Zone3 .', price='$33.00', number_of_reviews=76, review_scores_rating=4.57),
#  Row(name='One Queen bedroom flat', price='$126.00', number_of_reviews=30, review_scores_rating=4.83),
#  Row(name='Beautiful Mews House', price='$68.00', number_of_reviews=500, review_scores_rating=4.9),
#  Row(name='Small • Compact • Cosy Room - 10mins to station.', price='$36.00', number_of_reviews=500, review_scores_rating=4.93),
#  Row(name='Entire 2 Bedroom apart. In Tooting', price='$129.00', number_of_reviews=44, review_scores_rating=4.89),
#  Row(name='Large, quiet double bed with great WiFi Streatham', price='$45.00', number_of_reviews=37, review_scores_rating=4.89),
#  Row(name='Brixton Spacious house', price='$73.00', number_of_reviews=53, review_scores_rating=4.89),
#  Row(name='Charming Spacious room/ Chelsea Westminster', price='$61.00', number_of_reviews=232, review_scores_rating=4.56),
#  Row(name='Peaceful room in a cozy house', price='$30.00', number_of_reviews=49, review_scores_rating=4.88),
#  Row(name='Peaceful single bed compact small room', price='$27.00', number_of_reviews=96, review_scores_rating=4.88),
#  Row(name='Room with a view, nice neighbourhood ! Womens Only', price='$41.00', number_of_reviews=61, review_scores_rating=4.89),
#  Row(name='Small Neat Double Large Boutique Mansion Gardens', price='$51.00', number_of_reviews=70, review_scores_rating=4.91),
#  Row(name='Spacious high ceiling studio', price='$90.00', number_of_reviews=66, review_scores_rating=4.88),
#  ...]

# %%
# 6. Get a list of properties with the following characteristics:
# * price < 150 OR more than one bathroom
# Use the "|" operator to implement the OR operator
listings_with_price \
    .filter((col('price_numeric') < 150) | (col('bathrooms') > 1)) \
    .select('name', 'price', 'bathrooms') \
    .collect()
# Out:
# [Row(name='Holiday London DB Room Let-on going', price='$70.00', bathrooms=1.0),
#  Row(name='Bright Chelsea  Apartment. Chelsea!', price='$149.00', bathrooms=1.0),
#  Row(name='Very Central Modern 3-Bed/2 Bath By Oxford St W1', price='$411.00', bathrooms=2.0),
#  Row(name='Kew Gardens 3BR house in cul-de-sac', price='$280.00', bathrooms=1.5),
#  Row(name='You are GUARANTEED to love this', price='$90.00', bathrooms=0.0),
#  Row(name='SUNNY ROOM PRIVATE BATHROOM PLUS BREAKFAST', price='$61.00', bathrooms=1.0),
#  Row(name='Short Term Home', price='$340.00', bathrooms=2.0),
#  Row(name='SPACIOUS ROOM IN CONTEMPORARY STYLE FLAT', price='$49.00', bathrooms=1.0),
#  Row(name='Room with a view, shared flat,  central  Bankside', price='$96.00', bathrooms=1.0),
#  Row(name='You Will Save Money Here', price='$71.00', bathrooms=1.0),
#  Row(name='Quiet Comfortable Room in Fulham', price='$48.00', bathrooms=1.0),
#  Row(name='Room with a garden', price='$76.00', bathrooms=1.0),
#  Row(name='Pleasant Single Room in zone 1.', price='$50.00', bathrooms=1.0),
#  Row(name='Cosy Double studio in Zone 2 Hammersmith (6)', price='$78.00', bathrooms=1.0),
#  Row(name='Beautiful Small Studio Hammersmith', price='$79.00', bathrooms=1.0),
#  Row(name='Close to Wimbledon All England Tennis -huge double', price='$86.00', bathrooms=1.0),
#  Row(name='Cosy Double studio in Zone 2 Hammersmith (1)', price='$78.00', bathrooms=1.5),
#  Row(name='Cosy Double studio in Zone 2 Hammersmith (4)', price='$89.00', bathrooms=1.0),
#  Row(name='Cosy Double studio in Zone 2 Hammersmith (3)', price='$79.00', bathrooms=1.0),
#  Row(name='NICE FAMILY HOME opposite NATURAL LANDSCAPED PARK', price='$40.00', bathrooms=1.0),
#  Row(name='Spacious single room in quiet flat', price='$53.00', bathrooms=1.0),
#  Row(name='2 bed/2 bath luxury flat with city view!', price='$117.00', bathrooms=2.0),
#  Row(name='Peaceful Room Near Epping Forest', price='$106.00', bathrooms=1.0),
#  Row(name='Double Room 2 Miles from Wimbledon in Morden SM4', price='$35.00', bathrooms=1.0),
#  Row(name='Pretty Self Contained Coach House', price='$110.00', bathrooms=1.0),
#  Row(name='Family-friendly Airbnb in Fitzrovia', price='$417.00', bathrooms=2.0),
#  Row(name='Clerkenwell penthouse, huge terrace', price='$125.00', bathrooms=1.0),
#  Row(name='LONDON DETACHED HOUSE*ElecGates etc', price='$217.00', bathrooms=2.0),
#  Row(name='Spacious Bright Room in SE3', price='$43.00', bathrooms=1.0),
#  Row(name='Designer room Park Views 4 mins zone 1 station', price='$57.00', bathrooms=1.5),
#  Row(name='Maisonette in Central London Zone 1', price='$75.00', bathrooms=1.5),
#  Row(name='Lovely, spacious  garden apartment.', price='$145.00', bathrooms=1.0),
#  Row(name='Cosy, arty flat with roof terraces in Islington', price='$135.00', bathrooms=1.0),
#  Row(name='Luxury En-suite Room near Tube and River', price='$80.00', bathrooms=1.0),
#  Row(name='modern self contained flat islington', price='$90.00', bathrooms=1.0),
#  Row(name='Shown on T.V! Notting Hill Oasis', price='$350.00', bathrooms=2.0),
#  Row(name='Lovely Victorian Room Streatham', price='$60.00', bathrooms=1.0),
#  Row(name='Gorgeous Victorian Flat LONDON', price='$100.00', bathrooms=1.0),
#  Row(name='South Bank Bijou Studio Flat', price='$120.00', bathrooms=1.0),
#  Row(name='Lovely large room, Bethnal Green', price='$55.00', bathrooms=None),
#  Row(name='Double Room (Unavailable for check in 9-11 July)', price='$36.00', bathrooms=1.0),
#  Row(name='A stylish Victorian home in West London', price='$135.00', bathrooms=1.0),
#  Row(name='Contemporary central London apt', price='$156.00', bathrooms=1.5),
#  Row(name='Apartment close to centre.', price='$105.00', bathrooms=1.0),
#  Row(name='Limehouse London, Spacious Property', price='$76.00', bathrooms=1.0),
#  Row(name='Clerkenwell double', price='$83.00', bathrooms=1.0),
#  Row(name='Sunny stylish flat, with frequently absent Host', price='$90.00', bathrooms=1.0),
#  Row(name='West London,loft ensuite, 5min2tube', price='$58.00', bathrooms=1.5),
#  Row(name="A double Room 5mins from King's College Hospital", price='$42.00', bathrooms=1.0),
#  Row(name='Bright&Huge room close to Southside Wandsworth', price='$39.00', bathrooms=None),
#  Row(name='The Residential Suite Above Gallery', price='$131.00', bathrooms=1.0),
#  Row(name='Newly refurbished 2-bed apartment', price='$151.00', bathrooms=1.5),
#  Row(name='Quiet Double Room - Good for walks', price='$70.00', bathrooms=1.0),
#  Row(name='Private bathroom & spacious double room', price='$93.00', bathrooms=1.0),
#  Row(name='MODERN Self-Contained ARCHITECT FLAT', price='$108.00', bathrooms=1.0),
#  Row(name='Penthouse Living in East London', price='$45.00', bathrooms=1.0),
#  Row(name='London Whitechapel Room with WIFI', price='$44.00', bathrooms=1.0),
#  Row(name='LOVELY & COZY ROOM WITH KITCHENETTE', price='$23.00', bathrooms=1.0),
#  Row(name='Long Stay Cute Studio zone 1', price='$93.00', bathrooms=1.0),
#  Row(name='Private ensuite room in Harringay', price='$54.00', bathrooms=1.0),
#  Row(name='Room 20 min from central London', price='$36.00', bathrooms=None),
#  Row(name='Double room in family house - cost for 1 room only', price='$78.00', bathrooms=1.0),
#  Row(name='Shoreditch Loft', price='$151.00', bathrooms=1.5),
#  Row(name='Bright sunny apartment on garden square', price='$95.00', bathrooms=1.0),
#  Row(name='one Double bed room with en-suite facilities', price='$53.00', bathrooms=1.0),
#  Row(name='Cozy double room', price='$66.00', bathrooms=1.0),
#  Row(name='Five minute walk to South Bank', price='$71.00', bathrooms=1.5),
#  Row(name='Private room in London & cultural Islington', price='$50.00', bathrooms=1.0),
#  Row(name='Beautiful house in trendy E. London', price='$250.00', bathrooms=2.5),
#  Row(name='Stunning double room own bathroom', price='$380.00', bathrooms=4.0),
#  Row(name='Stylish Garden Studio | Large Kitchen + Smart TV', price='$100.00', bathrooms=1.0),
#  Row(name='Beautiful House Lower Clapton Hackney with garden', price='$160.00', bathrooms=1.5),
#  Row(name='Homely room in leafy Ealing.', price='$40.00', bathrooms=1.0),
#  Row(name='2 Bedroom London East End Apartment', price='$130.00', bathrooms=1.0),
#  Row(name='Huge Four Bedroom Apartment', price='$303.00', bathrooms=2.0),
#  Row(name='One Bedroom Apartment', price='$116.00', bathrooms=1.0),
#  Row(name='Spacious refurbished 2 bedroom apt with balcony', price='$187.00', bathrooms=2.0),
#  Row(name='Two Bedrooms Garden Maisonette', price='$148.00', bathrooms=2.0),
#  Row(name='One Bedroom Garden Apartment', price='$142.00', bathrooms=1.0),
#  Row(name='Four Bedroom Garden Apartment', price='$235.00', bathrooms=2.0),
#  Row(name='Huge Three Bedroom Flat with parking and terrace', price='$236.00', bathrooms=2.0),
#  Row(name='Also five minutes to South Bank', price='$66.00', bathrooms=1.5),
#  Row(name='Patio Apartment in London (Twickenham)', price='$74.00', bathrooms=1.0),
#  Row(name='Studio 20 min from center', price='$50.00', bathrooms=1.0),
#  Row(name='Great location, direct links to London Bridge!', price='$112.00', bathrooms=1.0),
#  Row(name='2 Bedroom  Cottage (E) with garden London', price='$122.00', bathrooms=1.0),
#  Row(name='Georgian Apartment in Bloomsbury', price='$140.00', bathrooms=1.0),
#  Row(name='Spacious luxury 2 bedroom apartment', price='$95.00', bathrooms=1.5),
#  Row(name='Stylish apartment in trendy Dalston', price='$117.00', bathrooms=1.0),
#  Row(name='Large single bedroom nr Canning Town (7 mins bus)', price='$32.00', bathrooms=1.0),
#  Row(name='Single room near Canning Town (7 mins by bus)', price='$37.00', bathrooms=1.5),
#  Row(name='Single Room in Creative House', price='$40.00', bathrooms=1.0),
#  Row(name='Home from Home in the heart of London', price='$118.00', bathrooms=1.0),
#  Row(name='A people person awaits you here!', price='$48.00', bathrooms=1.0),
#  Row(name='london is waiting for you', price='$57.00', bathrooms=None),
#  Row(name='Stylish 3 Bed 2 Bath Apartment Gdn + cafe culture', price='$189.00', bathrooms=2.0),
#  Row(name='Spacious Double Room in East London', price='$41.00', bathrooms=0.0),
#  Row(name='4 bedroom (+nursery) designer pad Belsize Park', price='$529.00', bathrooms=2.5),
#  Row(name='Double room no 1 near Brunel, Uxbridge, Heathrow', price='$45.00', bathrooms=1.0),
#  Row(name='A Modern Double Room in Greenwich.', price='$38.00', bathrooms=1.0),
#  Row(name="peaceful double room 5mins from King's Hospital", price='$44.00', bathrooms=1.0),
#  Row(name='LUXURIOUS  APART.30 MIN LONDON', price='$429.00', bathrooms=3.0),
#  Row(name='Comfy Family Home in London', price='$219.00', bathrooms=1.5),
#  Row(name='Double Room by Camden Market', price='$97.00', bathrooms=1.0),
#  Row(name='safe and spacious room in comfy family home', price='$26.00', bathrooms=1.0),
#  Row(name='Hotel-style room in Camden Town', price='$104.00', bathrooms=1.0),
#  Row(name='Fantastic location Double room', price='$95.00', bathrooms=1.0),
#  Row(name='Double Room in a Family House in Clapham/Battersea', price='$70.00', bathrooms=1.0),
#  Row(name='Stylish, Light Central London Flat', price='$70.00', bathrooms=1.0),
#  Row(name='Light spacious apartment', price='$114.00', bathrooms=1.0),
#  Row(name='Spacious Double Room (R3)', price='$58.00', bathrooms=2.0),
#  Row(name='Superior Boutique Comfort, Amazing Fast Transport', price='$37.00', bathrooms=2.0),
#  Row(name='Beautiful warehouse flat in London', price='$95.00', bathrooms=1.0),
#  Row(name='Stylish 2 Bed Apartment with Balcony', price='$96.00', bathrooms=1.0),
#  Row(name='Shepherds Bush W12 Double/Twin Room', price='$60.00', bathrooms=1.0),
#  Row(name='NICE DOUBLE ROOM IN A CLEAN  AND QUIET HOUSE', price='$26.00', bathrooms=1.5),
#  Row(name='Chiswick: Luxury 2 bed maisonette', price='$198.00', bathrooms=2.0),
#  Row(name='Homely Twin Room Streatham,London', price='$39.00', bathrooms=1.5),
#  Row(name='Homely Triple Room London 2', price='$39.00', bathrooms=1.5),
#  Row(name='1 bed flat near city.', price='$103.00', bathrooms=1.0),
#  Row(name='Luxury, Newly Renovated Chelsea Apartment', price='$200.00', bathrooms=2.5),
#  Row(name='Canary Wharf/Excel riverside luxury', price='$135.00', bathrooms=1.0),
#  Row(name='Gorgeous double at Camden Market', price='$83.00', bathrooms=1.5),
#  Row(name='High rise flat in Angel Islington', price='$99.00', bathrooms=1.0),
#  Row(name='Bright airy double room, central', price='$32.00', bathrooms=0.5),
#  Row(name='Loft near Canning Town station (7 mins by bus)', price='$36.00', bathrooms=1.0),
#  Row(name='Double room in lovely period house - friendly host', price='$37.00', bathrooms=1.0),
#  Row(name='London Vauxhall - Excellent Option!', price='$138.00', bathrooms=1.0),
#  Row(name='Pristine 5 Star Double Room, 1 Guest, Central W1', price='$115.00', bathrooms=1.0),
#  Row(name='Camden Town Duplex, with Downtown City Views', price='$192.00', bathrooms=1.5),
#  Row(name='Luxury Central London House with Gym and Reformer', price='$420.00', bathrooms=2.0),
#  Row(name='Unique Stylish Flat-Great Location!', price='$86.00', bathrooms=1.0),
#  Row(name='Vintage Oasis and Double Room and Peace', price='$51.00', bathrooms=1.0),
#  Row(name='Large sunny room, private bathroom, Dalston', price='$54.00', bathrooms=1.0),
#  Row(name='Cosy Town house with garden in London, Hackney', price='$275.00', bathrooms=2.0),
#  Row(name='2 Bedroom Garden Flat near Richmond', price='$223.00', bathrooms=2.0),
#  Row(name='White Room in Classic London Town House - Zone 2', price='$90.00', bathrooms=2.0),
#  Row(name='Serene Room in Classic London Town House - Zone 2', price='$107.00', bathrooms=2.0),
#  Row(name='Victorian Room in Classic London Townhouse -Zone 2', price='$81.00', bathrooms=2.0),
#  Row(name='Stunning Bright flat', price='$97.00', bathrooms=1.0),
#  Row(name="Large Dble Bdrm TV/Wifi nr NPL & St Mary's Uni", price='$45.00', bathrooms=1.0),
#  Row(name='Beautiful Victorian property on historic street', price='$57.00', bathrooms=1.0),
#  Row(name='Single bedroom', price='$50.00', bathrooms=1.0),
#  Row(name='Single room', price='$50.00', bathrooms=1.0),
#  Row(name='Heart of Notting Hill Garden Flat + cats', price='$80.00', bathrooms=1.0),
#  Row(name='Sunny dbl+parking nr Brixton market', price='$51.00', bathrooms=1.0),
#  Row(name='Small single room', price='$23.00', bathrooms=1.0),
#  Row(name='MORDEN London Zone 4, Bright Single Room', price='$20.00', bathrooms=1.0),
#  Row(name='Lovely family house. Up to 7 guests', price='$180.00', bathrooms=2.0),
#  Row(name='Comfortable/Friendly/Double room for 1/Limehouse', price='$38.00', bathrooms=1.0),
#  Row(name='Stylish Ensuite Room in house. - Maida Vale.', price='$83.00', bathrooms=1.0),
#  Row(name='Double room near tube', price='$50.00', bathrooms=1.0),
#  Row(name='Cozy room in lovely area!(Chiswick)', price='$72.00', bathrooms=1.0),
#  Row(name='Lovely Twin Room near to Common', price='$85.00', bathrooms=1.0),
#  Row(name='Lovely Smart Room', price='$53.00', bathrooms=1.5),
#  Row(name='Medium single room', price='$53.00', bathrooms=1.5),
#  Row(name='Twin-bedded sitting-room, 2 beds, 1 or 2 guests', price='$64.00', bathrooms=1.0),
#  Row(name='Sunny single free WiFi  Nr Richmond', price='$41.00', bathrooms=1.0),
#  Row(name='Maida Vale,Double bed with private garden   Zone 2', price='$63.00', bathrooms=1.0),
#  Row(name='Private Bedroom & Bathroom Peaceful & Central', price='$81.00', bathrooms=1.0),
#  Row(name='Attractive, comfy single in Eltham', price='$33.00', bathrooms=1.5),
#  Row(name='Double room in South London', price='$42.00', bathrooms=1.5),
#  Row(name='Pimlico Pad', price='$120.00', bathrooms=2.0),
#  Row(name='Beautiful Blue Room', price='$59.00', bathrooms=1.0),
#  Row(name='Double bed with private bathroom-C. London 20min', price='$63.00', bathrooms=1.0),
#  Row(name='garden studio Ealing sleep up to 4', price='$87.00', bathrooms=1.0),
#  Row(name='Trendy London Double Room, Cafes and  Transport', price='$49.00', bathrooms=1.0),
#  Row(name='Newly Decorated Rooms with Double Beds', price='$39.00', bathrooms=1.0),
#  Row(name='Super small double in stunning home', price='$40.00', bathrooms=1.5),
#  Row(name='Bright & beautiful 3-bed/2-bath near Portobello Rd', price='$345.00', bathrooms=2.0),
#  Row(name='Beautiful East London Apartment', price='$135.00', bathrooms=1.0),
#  Row(name="Cosy and central St Luke's/Barbican single room", price='$74.00', bathrooms=1.0),
#  Row(name='Room available from 2022 is 3rd photo.', price='$114.00', bathrooms=1.0),
#  Row(name='South Kensington premier location', price='$195.00', bathrooms=2.0),
#  Row(name='Loft Extravaganza', price='$38.00', bathrooms=1.0),
#  Row(name='DYNAMITE views!', price='$110.00', bathrooms=1.0),
#  Row(name='Lovely room in Clapton, Hackney E5', price='$73.00', bathrooms=1.0),
#  Row(name='Beautiful Penthouse in Clapham', price='$127.00', bathrooms=1.0),
#  Row(name='Entire quiet spacious home', price='$105.00', bathrooms=1.0),
#  Row(name='Bright Rooftop Nest In Notting Hill', price='$126.00', bathrooms=1.0),
#  Row(name='Large Double Room for Short/Long Stay selfcatering', price='$31.00', bathrooms=2.5),
#  Row(name='QUEENS PARK / KILBURN FLAT', price='$83.00', bathrooms=1.5),
#  Row(name='Lovely loft room with stylish en-suite.', price='$66.00', bathrooms=2.5),
#  Row(name='Lovely, Comfi and Cozy room for two', price='$23.00', bathrooms=1.0),
#  Row(name='Great Camden flat near Hampstead Heath', price='$85.00', bathrooms=1.0),
#  Row(name='Lovely 2 bedroom flat near Brixton, zone 2, London', price='$135.00', bathrooms=2.0),
#  Row(name='Hackney Stylish & light 1 bedroom Victorian flat', price='$123.00', bathrooms=1.0),
#  Row(name='1bed flat, Vauxhall, Central London', price='$149.00', bathrooms=1.0),
#  Row(name='Large double bedroom in Shoreditch w/garden', price='$127.00', bathrooms=1.5),
#  Row(name='Bedroom In Great Location Stratford', price='$52.00', bathrooms=1.5),
#  Row(name='Double Room and Workspace in spacious Garden Flat', price='$54.00', bathrooms=1.0),
#  Row(name='Sunny double room/balcony/shower/wc', price='$55.00', bathrooms=1.0),
#  Row(name='London, Ealing, W13 Artists Home', price='$80.00', bathrooms=1.0),
#  Row(name='Attic Room in historic Greenwich', price='$41.00', bathrooms=1.0),
#  Row(name='Very Central! Bayswater Apartment', price='$587.00', bathrooms=2.0),
#  Row(name='202 double room shower Soho comfy', price='$90.00', bathrooms=1.0),
#  Row(name='Dream Apartment in central London', price='$62.00', bathrooms=1.0),
#  Row(name="Architect's pub conversion, London", price='$78.00', bathrooms=1.0),
#  Row(name='Ensuite room in artist lofty studio', price='$120.00', bathrooms=1.0),
#  Row(name='800 ft² Riverside Stylish Private 2BED/2BATH SUITE', price='$154.00', bathrooms=2.0),
#  Row(name='Stay with us and Experience London!', price='$41.00', bathrooms=1.5),
#  Row(name='Spacious Double/Triple near Common', price='$85.00', bathrooms=1.0),
#  Row(name='Stunning large room (double sofa bed), Hackney, E9', price='$76.00', bathrooms=1.5),
#  Row(name='Adorable Big 2Bedroom/2Bathroom Battersea on River', price='$136.00', bathrooms=2.0),
#  Row(name='2BDR Riverside Suite in Battersea-private entrance', price='$153.00', bathrooms=2.0),
#  Row(name='Elegant, Boutique Apartment w/ roof terraces', price='$290.00', bathrooms=3.0),
#  Row(name='Peaceful loft in the trendy East End', price='$70.00', bathrooms=1.0),
#  Row(name='Great apartment in Hackney.', price='$77.00', bathrooms=1.0),
#  Row(name='Double Room Suiting Female Visitors to London', price='$43.00', bathrooms=1.0),
#  Row(name='A Self Contained Compact Ensuite Unit 400+ reviews', price='$67.00', bathrooms=1.0),
#  Row(name='3 bed House, Hackney, Victoria park E9', price='$238.00', bathrooms=1.5),
#  Row(name='Double Room in Victorian Terrace', price='$100.00', bathrooms=1.0),
#  Row(name='Great Quirky Twin room in Wimbledon', price='$67.00', bathrooms=1.5),
#  Row(name='Comfy Master Twin Room in Wimbledon', price='$55.00', bathrooms=1.5),
#  Row(name='Comfy B&B with Wifi & TV Wimbledon', price='$55.00', bathrooms=1.5),
#  Row(name='Fun Summer Garden Room - Wimbledon', price='$52.00', bathrooms=1.5),
#  Row(name='** OFFER! Modern and quiet, near Highgate Woods **', price='$105.00', bathrooms=1.0),
#  Row(name='Surprisingly Spacious & Stylish 2 Bed, 2 Bath Flat', price='$127.00', bathrooms=2.0),
#  Row(name='Exceptional garden maisonette', price='$175.00', bathrooms=1.5),
#  Row(name='ATTRACTIVE FLAT WITH ROOMS 4 RENTAL', price='$28.00', bathrooms=1.0),
#  Row(name='En-suite room in modern 2 bed flat', price='$68.00', bathrooms=1.0),
#  Row(name='Double bedroom overlooking garden', price='$69.00', bathrooms=1.5),
#  Row(name='East London flat on the Canal', price='$55.00', bathrooms=1.5),
#  Row(name='Double Room in Penthouse Flat', price='$135.00', bathrooms=1.0),
#  Row(name='A Unique & Spacious Urban Sanctuary', price='$600.00', bathrooms=2.5),
#  Row(name='Double Room in lovely family home', price='$56.00', bathrooms=1.0),
#  Row(name='Bridgerton inspired cottage core apartment', price='$91.00', bathrooms=1.0),
#  Row(name='Comfortable room to stay in London.', price='$37.00', bathrooms=1.5),
#  Row(name='Spacious Room in Limehouse, near QMUL', price='$61.00', bathrooms=1.5),
#  Row(name='WOW London Garden  Apartment', price='$137.00', bathrooms=2.5),
#  Row(name='Triple room for cheap price in London', price='$63.00', bathrooms=3.0),
#  Row(name='Cosy Double Room Central Kingston SW London', price='$53.00', bathrooms=1.0),
#  Row(name='London Bridge spacious apartment', price='$129.00', bathrooms=1.0),
#  Row(name='Chiswick Place - Home for up to 3 guests', price='$82.00', bathrooms=1.0),
#  Row(name='Central flat  Bankside  London Bridge Tate Modern', price='$140.00', bathrooms=1.0),
#  Row(name='Charming loft in NW3 mews close Belsize Park tube', price='$129.00', bathrooms=1.0),
#  Row(name='Sunny and peaceful loft studio London W12', price='$66.00', bathrooms=1.5),
#  Row(name='Stylish Spacious Apartment in Battersea', price='$130.00', bathrooms=1.0),
#  Row(name='Twin Room in Shoreditch', price='$49.00', bathrooms=1.0),
#  Row(name='Modern & bright flat near Portobello market', price='$135.00', bathrooms=1.0),
#  Row(name='Bright single room (Women only)', price='$69.00', bathrooms=1.0),
#  Row(name='Room to let for short stay', price='$60.00', bathrooms=None),
#  Row(name='Peaceful retreat  to Central London', price='$55.00', bathrooms=1.0),
#  Row(name='Single room North London', price='$38.00', bathrooms=1.5),
#  Row(name='Stunning views over Central London!', price='$145.00', bathrooms=1.5),
#  Row(name='Cosy room in shared Edwardian house', price='$38.00', bathrooms=1.5),
#  Row(name='3 bedroom, 3 bathroom house London', price='$176.00', bathrooms=3.0),
#  Row(name='Boutique double room with desk. Homerton, Hackney.', price='$55.00', bathrooms=1.0),
#  Row(name="'Vie de Boheme' in Central London", price='$119.00', bathrooms=1.0),
#  Row(name="Lovely bright room in Queen's Park", price='$78.00', bathrooms=1.5),
#  Row(name='Still the green side of Camden - Primrose Hill', price='$100.00', bathrooms=1.0),
#  Row(name='Double room in lovely north London flat', price='$42.00', bathrooms=1.0),
#  Row(name='Nice Room in Verdent Lane, Catford', price='$37.00', bathrooms=2.0),
#  Row(name='lovely private attic room with road and sky view', price='$41.00', bathrooms=1.0),
#  Row(name='2-bed garden house in Shoreditch', price='$216.00', bathrooms=1.5),
#  Row(name='Beautiful Historic 3 bedroom House Angel Islington', price='$357.00', bathrooms=2.0),
#  Row(name='GREAT VALUE ROOM- SAVE £££££', price='$39.00', bathrooms=2.0),
#  Row(name='Spacious flat close to city', price='$67.00', bathrooms=1.0),
#  Row(name='B&B with en-suite shower in a friendly family home', price='$56.00', bathrooms=0.0),
#  Row(name='Large bright dbl rm w-hampstead-1', price='$55.00', bathrooms=2.0),
#  Row(name='Self-catering room in Belsize Park', price='$65.00', bathrooms=1.0),
#  Row(name='5 bed house, Islington, Big garden!', price='$544.00', bathrooms=2.5),
#  Row(name='Twin Bed Room -  Acton/Shepherds Bush (SGL or DBL)', price='$59.00', bathrooms=1.0),
#  Row(name='Amazing Double Room In London', price='$69.00', bathrooms=1.0),
#  Row(name='West Kensington/Barons Court zone 2', price='$46.00', bathrooms=1.0),
#  Row(name='LUXURY APT. NEAR BUCKINGHAM PALACE', price='$901.00', bathrooms=3.0),
#  Row(name='Experience London in amazing reconverted Gin house', price='$276.00', bathrooms=3.5),
#  Row(name='Elegant Paddington Penthouse 2 Bedroom 3 Bathroom', price='$998.00', bathrooms=3.0),
#  Row(name='Double bedroom in South West London', price='$65.00', bathrooms=None),
#  Row(name='Big Bright room with your own private garden 2 use', price='$31.00', bathrooms=1.5),
#  Row(name='Picturesque Arts and Crafts Cottage', price='$27.00', bathrooms=1.5),
#  Row(name='Boutique style Bedroom with private bathroom', price='$55.00', bathrooms=1.0),
#  Row(name='1 bedroom in a 2 bedroom flat in south kensington', price='$92.00', bathrooms=1.0),
#  Row(name='Queer, veggie home to share', price='$52.00', bathrooms=1.0),
#  Row(name='Upper St. flat (Angel/Highbury& Islington)', price='$86.00', bathrooms=1.0),
#  Row(name='Private Room Close To Brick Lane', price='$32.00', bathrooms=1.5),
#  Row(name='Entire garden apartment in S London', price='$76.00', bathrooms=1.0),
#  Row(name='Blue Room in Classic London Townhouse - Zone 2', price='$90.00', bathrooms=2.0),
#  Row(name='Beautiful Family Home in Alexandra Palace', price='$197.00', bathrooms=2.0),
#  Row(name='Shoreditch/The City/Spitalfields', price='$63.00', bathrooms=1.0),
#  Row(name='Double room en suite Wanstead, park & metro London', price='$90.00', bathrooms=1.0),
#  Row(name='Beautiful Scandi inspired, magazine featured home!', price='$380.00', bathrooms=3.5),
#  Row(name='Explore London. Stay in 1 bed flat with Cat', price='$100.00', bathrooms=1.0),
#  Row(name='London, Zone 1, Central London Safe Private Room', price='$49.00', bathrooms=1.0),
#  Row(name='En-suite room Arsenal/Highbury', price='$87.00', bathrooms=1.0),
#  Row(name='Boutique house in Arsenal/Highbury', price='$298.00', bathrooms=2.0),
#  Row(name='Newly refurbished, 2 bedroom self-contained flat', price='$250.00', bathrooms=2.0),
#  Row(name='Luxury at 22 Dalyell! Perfect Location!', price='$105.00', bathrooms=1.0),
#  Row(name='Great 2 bed flat: trendy Bermondsey', price='$131.00', bathrooms=2.0),
#  Row(name='Walk to the Olympic Stadium!', price='$121.00', bathrooms=1.0),
#  Row(name='Private Log Cabin - Close to airport and metro', price='$37.00', bathrooms=1.0),
#  Row(name='Stunning London Home, IDEAL location', price='$580.00', bathrooms=2.0),
#  Row(name='Stylish flat by Battersea Power Station', price='$119.00', bathrooms=1.0),
#  Row(name='Central-light-spacious-lovely-room', price='$57.00', bathrooms=1.5),
#  Row(name='New beautiful En Suite in south Tottenham', price='$50.00', bathrooms=1.0),
#  Row(name='Double bedroom in East London', price='$70.00', bathrooms=1.5),
#  Row(name='Comfortable single room in tranquil neighbourhood', price='$34.00', bathrooms=1.0),
#  Row(name='Private King - Room  East London', price='$33.00', bathrooms=1.5),
#  Row(name='Beautiful room in Victorian house', price='$72.00', bathrooms=1.0),
#  Row(name='Bright, spacious bedroom with own shower room', price='$100.00', bathrooms=1.0),
#  Row(name='Self-contained studio appartment with private bath', price='$70.00', bathrooms=1.0),
#  Row(name='A warm, bright, spacious, beautiful one bed flat', price='$95.00', bathrooms=1.0),
#  Row(name='Bright Nice ROOM Shoreditch Haggerston Avail', price='$43.00', bathrooms=1.5),
#  Row(name='Highgate Village, North London', price='$47.00', bathrooms=1.5),
#  Row(name='Nice spacious room', price='$37.00', bathrooms=1.0),
#  Row(name='Fabulous 1bed Victorian Flat – Home away from Home', price='$78.00', bathrooms=1.5),
#  Row(name='Newly converted loft, 2 bedrooms, bath, kitchen', price='$105.00', bathrooms=1.0),
#  Row(name='Room near Portobello & Paddington', price='$54.00', bathrooms=1.0),
#  Row(name='Next to Hyde Park, London W2', price='$308.00', bathrooms=2.0),
#  Row(name='Outstanding location Kensington', price='$100.00', bathrooms=1.5),
#  Row(name='Well equipped spacious super king bed w/view zone2', price='$74.00', bathrooms=1.0),
#  Row(name='Lovely Double in Islington Near tube. Zone 2', price='$42.00', bathrooms=1.0),
#  Row(name='Your Place in Little Venice; 15 mins to West End', price='$396.00', bathrooms=2.0),
#  Row(name='Stylish Private Retro Hackney Studio Apartment', price='$102.00', bathrooms=1.0),
#  Row(name='A beautiful little flat in Camden', price='$116.00', bathrooms=1.5),
#  Row(name='Lovely Victorian home - trendy area', price='$230.00', bathrooms=2.0),
#  Row(name='Spacious & Bright with terrace', price='$72.00', bathrooms=1.0),
#  Row(name='Excellent Shoreditch apartment - massive discount', price='$122.00', bathrooms=1.0),
#  Row(name='BEST LOCATION in Central London', price='$133.00', bathrooms=1.0),
#  Row(name='Modern stylish child friendly flat in Queens Park', price='$130.00', bathrooms=1.5),
#  Row(name='Wimbledon studio 350 m from Tennis', price='$133.00', bathrooms=1.0),
#  Row(name='Double room in beautiful Victorian home', price='$46.00', bathrooms=2.0),
#  Row(name='Notting Hill Beautiful ensuite Room', price='$113.00', bathrooms=1.5),
#  Row(name='Cosy Double bed Broadway Mkt Hackney', price='$75.00', bathrooms=1.0),
#  Row(name='Spacious Designer Garden Flat in Hackney', price='$133.00', bathrooms=1.0),
#  Row(name='NICE COSY DOUBLE ROOMS FORSHORT LET', price='$35.00', bathrooms=0.5),
#  Row(name='Lovely dble room in vibrant E.Ldn', price='$89.00', bathrooms=2.0),
#  Row(name='Bright Double near Greenwich Park', price='$74.00', bathrooms=1.0),
#  Row(name='COSY HUB | Piccadilly Line | 20 m Cent. London', price='$42.00', bathrooms=1.5),
#  Row(name='Studio with separate kitchen,  garden view', price='$100.00', bathrooms=1.0),
#  Row(name='Stay close to Olympic Village', price='$60.00', bathrooms=None),
#  Row(name='Cosy twin room in lovely Victorian Home', price='$36.00', bathrooms=1.0),
#  Row(name='Great Sunny Room nr Notting Hill', price='$42.00', bathrooms=1.5),
#  Row(name='Comfortable Private Bedroom in Greenwich near 02', price='$44.00', bathrooms=1.0),
#  Row(name='studio 10', price='$89.00', bathrooms=1.0),
#  Row(name='Charming Notting Hill Garden Flat', price='$142.00', bathrooms=1.0),
#  Row(name='Fab double room 4 mins from tube', price='$40.00', bathrooms=1.5),
#  Row(name='Great double room 4 mins from tube!', price='$43.00', bathrooms=1.5),
#  Row(name='Flat in Private Historical Building', price='$115.00', bathrooms=1.5),
#  Row(name='Great Double Rooms In London City', price='$59.00', bathrooms=2.0),
#  Row(name='Stylish Spacious Warehouse Conversion Dalston Mews', price='$145.00', bathrooms=1.0),
#  Row(name='Double room in Shoreditch', price='$49.00', bathrooms=1.0),
#  Row(name='**Lovely Double Room + Wifi**', price='$25.00', bathrooms=1.0),
#  Row(name='Cosy room, incredible location: Covent Garden/Soho', price='$146.00', bathrooms=1.0),
#  Row(name='Charming Flat  in Chelsea', price='$147.00', bathrooms=0.0),
#  Row(name='Sm double room  with own bathroom', price='$38.00', bathrooms=1.0),
#  Row(name='Lovely room in a quiet area', price='$49.00', bathrooms=1.0),
#  Row(name='Private Room in Clerkenwell in Central London', price='$60.00', bathrooms=None),
#  Row(name='Sunny garden flat in Wimbledon', price='$104.00', bathrooms=1.0),
#  Row(name='Spacious Double Room Central Kingston SW London', price='$84.00', bathrooms=1.0),
#  Row(name='Twin Bedded Room in clean house', price='$44.00', bathrooms=1.0),
#  Row(name='Single Room to let in Clean House', price='$35.00', bathrooms=1.0),
#  Row(name='Stylish ensuite room  along peaceful canal', price='$65.00', bathrooms=2.0),
#  Row(name='4 minute walk to Tower Bridge, 2 bedrooms, wifi.', price='$257.00', bathrooms=1.5),
#  Row(name='Extra Large Double Bedroom', price='$55.00', bathrooms=1.0),
#  Row(name='SPACIOUS ROOM IN ARTISTIC BUNGALOW', price='$43.00', bathrooms=1.0),
#  Row(name='BEAUTIFUL COSY CHELSEA FLAT', price='$44.00', bathrooms=1.0),
#  Row(name='Veggie Vegan Ensuite Near Brick Lane', price='$54.00', bathrooms=1.0),
#  Row(name='Modern Triple Studio  Zone 2 Hammersmith (5)', price='$105.00', bathrooms=1.5),
#  Row(name='Zone 2 Dbl bed 1GB WiFi Private WC Shower. Nr park', price='$76.00', bathrooms=1.0),
#  Row(name='Cosy Room near Elizabeth line', price='$28.00', bathrooms=1.0),
#  Row(name='ENTIRE Chic Apartment in Central London, sleeps 5.', price='$98.00', bathrooms=1.0),
#  Row(name='RIVERSIDE Cosy SECURE double rm-hotel style shower', price='$57.00', bathrooms=1.0),
#  Row(name='short to medium term airbnb singles/c Lon/Hydepark', price='$100.00', bathrooms=1.0),
#  Row(name="SUPER XL ATTIC | Piccadilly Line | 16m KING'S X", price='$36.00', bathrooms=1.5),
#  Row(name='Room in Designer House Notting Hill', price='$86.00', bathrooms=1.0),
#  Row(name='Stunning Kings X Penthouse with Huge Sun Terrace', price='$184.00', bathrooms=2.0),
#  Row(name='Spacious Double Bedrooms in Fulham/Hammersmith', price='$78.00', bathrooms=1.5),
#  Row(name='3 Double Rooms by River in Fulham shared house', price='$78.00', bathrooms=1.0),
#  Row(name='Large bedroom in a family house', price='$55.00', bathrooms=1.0),
#  Row(name='Double room Camden designer flat with own bathroom', price='$94.00', bathrooms=1.0),
#  Row(name='London room - 15 mins to Eurostar', price='$45.00', bathrooms=1.5),
#  Row(name='Spacious 2 bed flat Ealing sleeps one family of 5', price='$149.00', bathrooms=1.5),
#  Row(name='Notting Hill Garden Studio Room +Cats', price='$75.00', bathrooms=1.0),
#  Row(name='Come enjoy our hospitality', price='$48.00', bathrooms=1.0),
#  Row(name='Stylish 5 bed house in Islington with large garden', price='$356.00', bathrooms=2.0),
#  Row(name='West Kensington central London', price='$49.00', bathrooms=1.0),
#  Row(name='Regents Canal', price='$152.00', bathrooms=1.5),
#  Row(name='Shoreditch with Garden!!!', price='$122.00', bathrooms=1.0),
#  Row(name='Fulham, Earls Crt.Dble  rm-£65 single/£95 2 guests', price='$65.00', bathrooms=1.0),
#  Row(name='Luxury home, good location', price='$280.00', bathrooms=2.0),
#  Row(name='Framery Loft', price='$228.00', bathrooms=2.0),
#  Row(name='LAST MINUTE - SINGLE ROOM', price='$33.00', bathrooms=2.0),
#  Row(name='One bed chic flat in Trendy Dalston', price='$123.00', bathrooms=1.0),
#  Row(name='3 Bed 2 Bath Warehouse loft Zone 1', price='$411.00', bathrooms=2.0),
#  Row(name='Large private flat close to central London', price='$113.00', bathrooms=1.0),
#  Row(name='Single Cosy Room+FastWifi No snorers/3 mins shop', price='$41.00', bathrooms=1.0),
#  Row(name='Beautiful room in lovely home.', price='$77.00', bathrooms=1.0),
#  Row(name='Beautiful En-suite Room in London', price='$60.00', bathrooms=1.0),
#  Row(name='Cosy central clean close to tube single room 1-2 p', price='$61.00', bathrooms=1.0),
#  Row(name='Lovely Knightsbridge Flat - central, quiet, garden', price='$143.00', bathrooms=1.0),
#  Row(name='En-Suite, Big, Sunny Double', price='$58.00', bathrooms=2.0),
#  Row(name='Your London home away from home', price='$131.00', bathrooms=1.0),
#  Row(name='Lovely room suitable for lady only', price='$27.00', bathrooms=1.0),
#  Row(name='2 Bed flat with garden in West Hampstead', price='$348.00', bathrooms=1.5),
#  Row(name='Calm Luxe Hotel Styled 2 Bed in Vibrant Brixton', price='$132.00', bathrooms=1.0),
#  Row(name='Fabulous flat for foodies and city explorers', price='$96.00', bathrooms=1.5),
#  Row(name='Airy Loft Studio with en-suite bathroom', price='$86.00', bathrooms=1.0),
#  Row(name='Lovely room - London SE23 - 30 mins to central', price='$82.00', bathrooms=1.0),
#  Row(name='Stunning house with large garden,', price='$490.00', bathrooms=3.0),
#  Row(name='Single room in large house Gospel Oak/Tufnell Park', price='$55.00', bathrooms=1.5),
#  Row(name='Lovely Edwardian terraced house.', price='$219.00', bathrooms=1.5),
#  Row(name='Room in 2 Bedroom Flat with balcony', price='$139.00', bathrooms=1.0),
#  Row(name='1-BD Flat In The Heart Of Hoxton And Shoreditch', price='$67.00', bathrooms=1.0),
#  Row(name='Stunning Art Deco flat East London', price='$121.00', bathrooms=1.0),
#  Row(name='Well reviewed in quiet residential area of London', price='$149.00', bathrooms=1.0),
#  Row(name='ZONE 1 - Spacious 1 bed Flat Close to amenities', price='$127.00', bathrooms=1.0),
#  Row(name='Gorgeous 1st floor apartment - 1 min from station', price='$134.00', bathrooms=1.0),
#  Row(name='BEAUTIFUL STUDIO SKYLINES  wifi WHOLE FLAT', price='$100.00', bathrooms=1.0),
#  Row(name='BALCONY/OVERLOOKING RUGBY GROUND WI FI  WHOLE FLAT', price='$99.00', bathrooms=1.0),
#  Row(name='private dblbedroom in Ham/ Richmond', price='$60.00', bathrooms=1.0),
#  Row(name='Studio Flat off Sutton High Street (Ground Flr)', price='$53.00', bathrooms=1.0),
#  Row(name='3Bedroom apartment, 2Bathrooms, 20min. City Centre', price='$168.00', bathrooms=2.0),
#  Row(name='Private Bath Family room - London Bridge 1 stop', price='$75.00', bathrooms=1.0),
#  Row(name='Dble Room+Wi-Fi-Arsenal/Clissold park/North London', price='$63.00', bathrooms=1.0),
#  Row(name='Modern 3 Bed Greenwich apartment on the river 0131', price='$191.00', bathrooms=2.0),
#  Row(name='ROOM EN-SUITE BATHROOM Heathrow & Film studios', price='$45.00', bathrooms=1.0),
#  Row(name='London house with en-suite rooms 5', price='$55.00', bathrooms=1.0),
#  Row(name='Bright London spaceious overlooking rugby ground', price='$80.00', bathrooms=1.0),
#  Row(name='Lovely, double room in Kensington Olympia', price='$86.00', bathrooms=1.0),
#  Row(name='Cosy Medium sized room in Shepherds Bush', price='$53.00', bathrooms=1.0),
#  Row(name='Cosy double', price='$75.00', bathrooms=0.0),
#  Row(name='Modern Triple Studio Zone 2 Hammersmith (10)', price='$90.00', bathrooms=1.0),
#  Row(name='Beautiful one bed in the heart of Notting Hill', price='$104.00', bathrooms=1.0),
#  Row(name='Prime location luxury home', price='$912.00', bathrooms=3.5),
#  Row(name='Lovely 4 bed house Highgate, London', price='$275.00', bathrooms=1.5),
#  Row(name='Super Fast Transport, Superior Boutique Comfort', price='$45.00', bathrooms=2.0),
#  Row(name='Beautiful warehouse-style room in Hackney.', price='$48.00', bathrooms=1.0),
#  Row(name='Contemporary & Bright Flat Fulham', price='$136.00', bathrooms=1.0),
#  Row(name='Light, bright room North London', price='$32.00', bathrooms=1.0),
#  Row(name='Double ensuite+terrace', price='$95.00', bathrooms=1.0),
#  Row(name='Kensington-2 Bed 1.5 Bath-portered', price='$241.00', bathrooms=1.5),
#  Row(name='Small, cosy, garden DOUBLE room with bathroom', price='$53.00', bathrooms=2.0),
#  Row(name='Double Room Close to Tube Quiet Rd', price='$68.00', bathrooms=1.5),
#  Row(name='Gated Central Camden 2B modern and quiet apartment', price='$249.00', bathrooms=2.0),
#  Row(name='Cosy Shoreditch Studio in ArtDecoCinema Conversion', price='$111.00', bathrooms=1.0),
#  Row(name='One bedroom near station', price='$92.00', bathrooms=1.0),
#  Row(name='South London Garden Studio for two', price='$27.00', bathrooms=1.0),
#  Row(name='Beautiful Non Smoking London Home', price='$135.00', bathrooms=1.0),
#  Row(name='Shoreditch Central/East London Lively Zone 1', price='$50.00', bathrooms=1.0),
#  Row(name='Spacious and quiet 2-bedroom and 2-bathroom flat', price='$175.00', bathrooms=2.0),
#  Row(name='3BR Flat Ideal for O2, Excel 0168', price='$246.00', bathrooms=2.0),
#  Row(name='Space in well equipped London pad', price='$50.00', bathrooms=1.0),
#  Row(name='Lovely Modern Quiet En-suite Studio Room', price='$63.00', bathrooms=1.0),
#  Row(name='Waterloo Heights Deluxe', price='$54.00', bathrooms=1.0),
#  Row(name='Stepney House - affordable luxury', price='$90.00', bathrooms=1.5),
#  Row(name='Quiet single room in Fulham', price='$51.00', bathrooms=1.0),
#  Row(name='Double Room close to Camberwell College and Kings', price='$44.00', bathrooms=1.0),
#  Row(name='Sofa bed in the living room looks out to garden', price='$27.00', bathrooms=1.0),
#  Row(name='Stepney House 2 - affordable Luxury', price='$87.00', bathrooms=1.5),
#  Row(name='Peaceful twin room, quiet home, easy for Heathrow', price='$61.00', bathrooms=1.0),
#  Row(name='Spacious Double in shared home close to Heathrow', price='$61.00', bathrooms=1.0),
#  Row(name='Arty House 8min walk from Tennis', price='$270.00', bathrooms=1.5),
#  Row(name='Wimbledon Village Sleeps 3 Cute Cottage', price='$116.00', bathrooms=1.0),
#  Row(name='Brilliantly Located Apartment', price='$77.00', bathrooms=1.0),
#  Row(name='Richmond on Thames Huge quiet private  Studio!', price='$135.00', bathrooms=1.0),
#  Row(name='Light & spacious family house, Kensal Rise, London', price='$405.00', bathrooms=3.5),
#  Row(name='Stunning 2 Bedroom Flat in West Hampstead', price='$345.00', bathrooms=1.5),
#  Row(name='Single Room+Fast Wi-Fi/No snorers', price='$33.00', bathrooms=1.0),
#  Row(name='7 Bedroom, 3 bathrooms, Garden, 20 mins to centre', price='$264.00', bathrooms=3.0),
#  Row(name='Parkside Arty & Central Zone 2,  Brixton', price='$230.00', bathrooms=2.0),
#  Row(name='Cosy double room in welcoming home.', price='$63.00', bathrooms=1.0),
#  Row(name='Stunning Roof Terraced Flat London', price='$223.00', bathrooms=1.5),
#  Row(name='Gorgeous 1 Bed garden flat, Camden !!33% OFF!!', price='$129.00', bathrooms=1.0),
#  Row(name='Stunning 2bed 2bath in Central London', price='$412.00', bathrooms=2.0),
#  Row(name='Double with bathroom in LGBT friendly home', price='$85.00', bathrooms=1.0),
#  Row(name='Twin room, Close to Underground Quiet Road', price='$68.00', bathrooms=1.5),
#  Row(name='Single Room Close To Tube Quiet Rd', price='$44.00', bathrooms=1.5),
#  Row(name='Stepney House 3 - affordable LUXURY', price='$235.00', bathrooms=2.5),
#  Row(name='London house with en-suite rooms 2', price='$55.00', bathrooms=1.0),
#  Row(name='London house with en-suite rooms 1', price='$55.00', bathrooms=1.0),
#  Row(name='London house with en-suite rooms 4', price='$55.00', bathrooms=1.0),
#  Row(name='Large and spacious  family bedroom', price='$43.00', bathrooms=1.5),
#  Row(name='Nice single room with small double bed', price='$38.00', bathrooms=1.0),
#  Row(name='Private Room in Central London', price='$60.00', bathrooms=1.0),
#  Row(name='Beautiful location cosy Studio flat', price='$80.00', bathrooms=1.0),
#  Row(name='Central, Camden, Hampstead Dbl Room, Bath & Lounge', price='$90.00', bathrooms=1.0),
#  Row(name="The Lookout: London's Panoramic 3 Bed", price='$600.00', bathrooms=2.0),
#  Row(name='Charming 1 bedroom house with 2 bathrooms', price='$110.00', bathrooms=2.0),
#  Row(name='Cosy apartment in Covent Garden', price='$147.00', bathrooms=1.0),
#  Row(name='Gorgeous family riverside flat', price='$111.00', bathrooms=1.0),
#  Row(name='Charming room in Kings Cross', price='$72.00', bathrooms=1.0),
#  Row(name='double garden bedroom with ensuite', price='$70.00', bathrooms=0.0),
#  Row(name='Crayford - Camden Islington', price='$124.00', bathrooms=1.0),
#  Row(name='1BR Apartment in Zone 2 South London_Georgeous!', price='$99.00', bathrooms=1.0),
#  Row(name='Large double room with private en-suite bathroom', price='$95.00', bathrooms=1.0),
#  Row(name='Charming Studio with Patio Garden', price='$125.00', bathrooms=1.5),
#  Row(name='Stylish Apartment', price='$113.00', bathrooms=1.0),
#  Row(name='Penthouse Room with Views over Park, near Station', price='$54.00', bathrooms=1.0),
#  Row(name='Very big 1 bedroom flat in Central London', price='$66.00', bathrooms=1.0),
#  Row(name='Private Room, Central London – Stylish & Easy', price='$59.00', bathrooms=1.0),
#  Row(name='Sunny, spacious oasis in  the heart of Dalston', price='$51.00', bathrooms=2.5),
#  Row(name='Lovely town house in Herne Hill with 2 cute cats', price='$200.00', bathrooms=2.0),
#  Row(name='Modern One Bedroom Flat in Brixton', price='$49.00', bathrooms=1.0),
#  Row(name='Beautiful Double Room: downstairs', price='$50.00', bathrooms=1.0),
#  Row(name='1BD apartment in heart of London W1', price='$119.00', bathrooms=1.0),
#  Row(name='2 Bed West London Flat', price='$75.00', bathrooms=1.0),
#  Row(name='5* Stylish, spacious room.   (Zone 3 West Norwood)', price='$44.00', bathrooms=1.0),
#  Row(name='Double room  private bathroom  LGBT friendly home', price='$75.00', bathrooms=1.0),
#  Row(name='Large double room with private toilet/shower', price='$113.00', bathrooms=1.5),
#  Row(name='Private room with double bed', price='$40.00', bathrooms=1.0),
#  Row(name='Lovely, Sunny, Quiet Double', price='$40.00', bathrooms=1.0),
#  Row(name='Room with a view', price='$59.00', bathrooms=1.0),
#  Row(name='Comfortable Triple bunk beds & breakfast in London', price='$40.00', bathrooms=1.5),
#  Row(name='Outstanding Apartment in Camden', price='$500.00', bathrooms=2.5),
#  Row(name='Central London 10 mins by tube Bond St/Westminster', price='$142.00', bathrooms=1.0),
#  Row(name='Ideal family room with twin beds and a big sofabed', price='$38.00', bathrooms=1.5),
#  Row(name='SW London-large modern flat. Great transport Links', price='$132.00', bathrooms=1.5),
#  Row(name='Double room (women or couples only)', price='$91.00', bathrooms=1.0),
#  Row(name='Light-filled room with own amenities.', price='$81.00', bathrooms=1.0),
#  Row(name='Arts and Crafts house, good transport', price='$58.00', bathrooms=2.0),
#  Row(name='Boutique bijoux garden flat in vibrant Oval', price='$72.00', bathrooms=1.0),
#  Row(name='1BD apartment in Trendy Dalston', price='$68.00', bathrooms=1.0),
#  Row(name='Modern apt in Trendy Dalston', price='$73.00', bathrooms=1.0),
#  Row(name='Stunning Flat with Private Garden', price='$67.00', bathrooms=1.0),
#  Row(name='Private room in London apartment', price='$43.00', bathrooms=1.0),
#  Row(name='Lovely Family friendly Rooms (no 4 and 5)', price='$143.00', bathrooms=1.0),
#  Row(name='Whole private self-contained studio @ Clapton Pond', price='$82.00', bathrooms=1.0),
#  Row(name='Double Room, OWN Bathroom, Zone 1!', price='$92.00', bathrooms=1.0),
#  Row(name='Bethnal Green, Period Mansion Block.', price='$65.00', bathrooms=1.0),
#  Row(name='Peaceful.Garden.Notting Hill', price='$51.00', bathrooms=1.0),
#  Row(name='Beautiful Victorian House & Garden', price='$225.00', bathrooms=2.0),
#  Row(name='Bright beautiful trendy London APT', price='$98.00', bathrooms=1.0),
#  Row(name='Lovely, Light London Family Home with garden.', price='$176.00', bathrooms=2.5),
#  Row(name='Spacious Room near QMUL, Limehouse, Mile End', price='$67.00', bathrooms=1.5),
#  Row(name='1 Bed Flat off Kentish Town High St', price='$110.00', bathrooms=1.5),
#  Row(name='Private Entrance En-Suite in beautiful Hampstead', price='$132.00', bathrooms=1.0),
#  Row(name='Relaxing Georgian house in London', price='$110.00', bathrooms=2.0),
#  Row(name='Sunny Single Room Finsbury Park', price='$61.00', bathrooms=1.0),
#  Row(name='South facing charming vibrant/cool Clapton/Hackney', price='$58.00', bathrooms=1.0),
#  Row(name='Modern room with an italian touch', price='$80.00', bathrooms=1.0),
#  Row(name='Comfortable Private Room, London, Redbridge,Zone4', price='$42.00', bathrooms=1.0),
#  Row(name='A private room for two in London in Zone 2', price='$55.00', bathrooms=1.0),
#  Row(name='Smart Medium Sized Room', price='$53.00', bathrooms=1.0),
#  Row(name='Dble room very near train st - no cleaning fee', price='$57.00', bathrooms=1.0),
#  Row(name='Hip, homely, and spacious flat in Hither Green', price='$111.00', bathrooms=1.0),
#  Row(name="Cosy double room, children's room and roof garden", price='$82.00', bathrooms=1.0),
#  Row(name='Cosy Stylish Flat by Canal in East London E2', price='$105.00', bathrooms=1.0),
#  Row(name='Gorgeous 1 bed flat, London Fields', price='$140.00', bathrooms=1.0),
#  Row(name='South Kensington Penthouse with large roof terrace', price='$233.00', bathrooms=2.0),
#  Row(name='Beautiful Double Room (R2)', price='$48.00', bathrooms=2.0),
#  Row(name='3 Bedroom Garden Flat - Central Location', price='$314.00', bathrooms=2.0),
#  Row(name='Quiet Haven in London/3rd bedroom', price='$175.00', bathrooms=1.5),
#  Row(name='London house with en-suite rooms 3', price='$55.00', bathrooms=1.0),
#  Row(name='Lovely self contained private studio room in W12', price='$95.00', bathrooms=1.0),
#  Row(name='Spasious double room in Hendon Central', price='$35.00', bathrooms=1.0),
#  Row(name='Chelsea Georgian terraced house with room', price='$73.00', bathrooms=1.5),
#  Row(name='Charming 1BD with private outside courtyard', price='$101.00', bathrooms=1.0),
#  Row(name='Chic Double En-Suite in Heart of West End', price='$58.00', bathrooms=1.0),
#  Row(name='Huge Warehouse Conversion', price='$265.00', bathrooms=2.0),
#  Row(name='room in central greenwich london', price='$43.00', bathrooms=1.0),
#  Row(name='Charming Living in Central London', price='$296.00', bathrooms=3.5),
#  Row(name='Cozy Fitzrovia studio on cobbled st', price='$127.00', bathrooms=1.0),
#  Row(name='Large bright dbl rm w-hampstead-2', price='$55.00', bathrooms=2.0),
#  Row(name='A Cosy Double Room Near The River!', price='$55.00', bathrooms=1.0),
#  Row(name='Comfortable, convenient flat in heart of Dalston', price='$145.00', bathrooms=1.0),
#  Row(name='West End - Third - Top floor - Superior apartment', price='$127.00', bathrooms=1.0),
#  Row(name='Stunning Notting Hill 3 bed home', price='$468.00', bathrooms=2.0),
#  Row(name='Central London Large Studio Flat', price='$114.00', bathrooms=1.0),
#  Row(name='Sunny flat with balcony in Battersea', price='$96.00', bathrooms=1.0),
#  Row(name='Family house in Hackney London', price='$350.00', bathrooms=1.5),
#  Row(name='Twin bed room with en suite SW19', price='$65.00', bathrooms=1.0),
#  Row(name='Large and modern room', price='$50.00', bathrooms=1.0),
#  Row(name='Double room/ensuite shower, London', price='$72.00', bathrooms=1.5),
#  Row(name='Central London Superior Apartment second floor', price='$132.00', bathrooms=1.0),
#  Row(name='Beautiful double bedroom', price='$45.00', bathrooms=1.0),
#  Row(name='Spacious room in Central London', price='$40.00', bathrooms=1.0),
#  Row(name='Luxury Marylebone 2-Bed Duplex with Terrace', price='$249.00', bathrooms=1.5),
#  Row(name='2 bedroom spacious garden flat (full use of flat)', price='$149.00', bathrooms=1.0),
#  Row(name='Spacious One Bedroom Private Flat in Brixton +Wifi', price='$90.00', bathrooms=1.0),
#  Row(name='Cosy & Stylish Double Room in Sunny Chiswick 1', price='$55.00', bathrooms=1.0),
#  Row(name='Fab Flat 15 Min Cntrl Lon', price='$167.00', bathrooms=2.0),
#  Row(name='Stylish Victorian House with Private Patio in West London', price='$500.00', bathrooms=2.0),
# ...
#  Row(name='Quiet Sgl. (private bathroom)Shirley/ West Wickham', price='$41.00', bathrooms=1.0),
#  Row(name='Cozy 1-Bedroom Flat in Queen’s Park', price='$123.00', bathrooms=1.0),
#  Row(name='Your entire Hoxton home Sleeps 3.  zone1.', price='$142.00', bathrooms=1.0),
#  Row(name='London En-Suite Loft Room', price='$43.00', bathrooms=1.0),
#  Row(name='A COSY single room in Enfield - Wi-Fi + Desk/Chair', price='$39.00', bathrooms=0.0),
#  Row(name='In the heart of exciting Shoreditch', price='$62.00', bathrooms=1.0),
#  Row(name='Bright Single London Room', price='$36.00', bathrooms=2.0),
#  Row(name='Bright & Airy Bedroom    suitable for Female Guest', price='$79.00', bathrooms=1.0),
#  Row(name='Large double room with ensuite', price='$78.00', bathrooms=1.0),
#  Row(name='Ensuite Private Room Haggerston Shoreditch Avail', price='$54.00', bathrooms=1.5),
#  Row(name='A lovely room and a warm welcome', price='$70.00', bathrooms=1.0),
#  Row(name='Riverside Double Room', price='$67.00', bathrooms=2.5),
#  Row(name='Clean, modern and contemporary room', price='$95.00', bathrooms=1.0),
#  Row(name='Private double room in Battersea apartment', price='$72.00', bathrooms=1.0),
#  Row(name='Bright bedroom with private bathroom in 2 bed flat', price='$57.00', bathrooms=1.0),
#  Row(name='Bright sunny single Finsbury Park', price='$61.00', bathrooms=1.0),
#  Row(name='relaxing tree view private bathroom terrace', price='$94.00', bathrooms=1.0),
#  Row(name='Luxury 2 Bedroom Flat with amazing view, Excel', price='$190.00', bathrooms=2.0),
#  Row(name='Cosy single room in Fulham', price='$48.00', bathrooms=1.0),
#  Row(name='Double room in West Kensington', price='$55.00', bathrooms=1.0),
#  Row(name='Central London 4 Bedroom Executive Apt Epic Views!', price='$135.00', bathrooms=1.5),
#  Row(name='Friendly home environment.', price='$31.00', bathrooms=1.5),
#  Row(name='Elegant Chelsea Apartment, Best location', price='$180.00', bathrooms=1.5),
#  Row(name='4 double bedrooms, Chiswick', price='$435.00', bathrooms=3.5),
#  Row(name='A great central London flat for exploring the City', price='$106.00', bathrooms=1.0),
#  Row(name='2 Minutes Walk To Camden Town Stn!', price='$105.00', bathrooms=1.0),
#  Row(name='6 bed Clapham Common Home Battersea', price='$600.00', bathrooms=4.0),
#  Row(name='2 Minutes Walk To Camden Town Stn!!', price='$123.00', bathrooms=1.0),
#  Row(name='Room Offered', price='$30.00', bathrooms=1.0),
#  Row(name='Stylish, family friendly house in Queens Park', price='$276.00', bathrooms=1.5),
#  Row(name='Small double room in fashionable Putney', price='$100.00', bathrooms=1.0),
#  Row(name='Luxurious double room in Putney with private bath', price='$114.00', bathrooms=1.0),
#  Row(name='Large double in fashionable Putney', price='$114.00', bathrooms=1.0),
#  Row(name='Single room with own bathroom for solo traveller', price='$48.00', bathrooms=1.0),
#  Row(name="Dbl Room, W'stow Central 2 mins", price='$50.00', bathrooms=1.0),
#  Row(name='Islington N1 Double Room Zone 1 Central London', price='$68.00', bathrooms=1.0),
#  Row(name='Beautiful EnSuite Room Central London', price='$108.00', bathrooms=1.0),
#  Row(name='Small south-facing room', price='$35.00', bathrooms=1.0),
#  Row(name='Spacious Studio Near Big Ben', price='$135.00', bathrooms=1.0),
#  Row(name='Spacious double bdr in charming house', price='$52.00', bathrooms=1.0),
#  Row(name='London Family Home near underground, sleeps 7', price='$140.00', bathrooms=2.0),
#  Row(name='Room with Balcony near Shoreditch', price='$44.00', bathrooms=1.0),
#  Row(name='Designers home Marylebone Mayfair space to relax', price='$550.00', bathrooms=2.5),
#  Row(name='Cozy elegant double bed & private bathroom', price='$86.00', bathrooms=1.0),
#  Row(name='Luxury 3BR townhouse,  office/playroom & XL garden', price='$450.00', bathrooms=3.0),
#  Row(name='Lovely double room close to Station', price='$79.00', bathrooms=1.0),
#  Row(name='Lovely room with Garden view 2', price='$50.00', bathrooms=2.0),
#  Row(name='CAMDEN,   KENTISH TOWN,  ZONE 2,  5min walk', price='$41.00', bathrooms=1.5),
#  Row(name='Boutique double bed / desk. Chatsworth Rd, Hackney', price='$55.00', bathrooms=1.0),
#  Row(name='Large Room + Private Bathroom, E3.', price='$60.00', bathrooms=1.0),
#  Row(name='Victorian Terrace quiet & spacious', price='$40.00', bathrooms=2.5),
#  Row(name='London rooms 3 in Victorian house', price='$45.00', bathrooms=1.0),
#  Row(name='Double bedroom in 2 bedroom flat', price='$59.00', bathrooms=1.5),
#  Row(name='Lovely Room In House Shepherds Bush', price='$65.00', bathrooms=1.0),
#  Row(name='Twin Room Hammersmith Kensington', price='$65.00', bathrooms=1.0),
#  Row(name='Unique Chiswick Roof Terrace Penthouse with London Views', price='$306.00', bathrooms=2.0),
#  Row(name='Single Room in Large Terraced House', price='$50.00', bathrooms=1.0),
#  Row(name='small bedroom bathroom ensuite near Olympia', price='$68.00', bathrooms=1.0),
#  Row(name='Beautiful spacious family home. North London', price='$285.00', bathrooms=1.5),
#  Row(name='Cosy double room, bathroom, Victorian, SW London', price='$65.00', bathrooms=1.0),
#  Row(name='Lovely family home in Kentish Town', price='$300.00', bathrooms=1.5),
#  Row(name='Bijou Victorian style apartment sleeps 4/7', price='$218.00', bathrooms=2.5),
#  Row(name='Charming flat in Golders Green with parking space', price='$133.00', bathrooms=1.0),
#  Row(name='Beautiful room 5min from West Acton', price='$50.00', bathrooms=2.0),
#  Row(name='Typical English Georgian terrace', price='$53.00', bathrooms=1.5),
#  Row(name='Perfect London Base', price='$80.00', bathrooms=1.0),
#  Row(name='Stunning garden flat, with a cat!', price='$101.00', bathrooms=1.0),
#  Row(name='stones throw from Wembley stadium', price='$95.00', bathrooms=1.0),
#  Row(name='Wapping/Limehouse | Near Narrow St. | River View', price='$63.00', bathrooms=1.0),
#  Row(name='The Pelton Arms', price='$74.00', bathrooms=2.0),
#  Row(name='Lovely flat in Central London.', price='$102.00', bathrooms=1.0),
#  Row(name='Elegant double bedroom, ensuite, South West London', price='$95.00', bathrooms=1.0),
#  Row(name='Penthouse Apartment', price='$184.00', bathrooms=2.0),
#  Row(name='Lovely decorated penthouse apartmen', price='$150.00', bathrooms=2.0),
#  Row(name='Amazing Spacious Private Suite', price='$85.00', bathrooms=1.0),
#  Row(name='Wimbledon Tennis Double Loft Bedroom', price='$39.00', bathrooms=1.0),
#  Row(name='1 bedroom garden flat, Barnsbury', price='$156.00', bathrooms=1.5),
#  Row(name='HUGE DOUBLE ROOM WITH MEZZANINE', price='$2,850.00', bathrooms=2.0),
#  Row(name='ISLINGTON Flat near Angel Tube', price='$87.00', bathrooms=1.0),
#  Row(name='Light, spacious studio in vibrant London Bridge', price='$143.00', bathrooms=1.0),
#  Row(name='Light, tranquil dbl room in arty Blackheath home', price='$55.00', bathrooms=1.0),
#  Row(name='Beautiful family home.', price='$770.00', bathrooms=3.5),
#  Row(name='Wonderful Holland Park Studio', price='$100.00', bathrooms=1.0),
#  Row(name='Small 1 bed apartment London center', price='$115.00', bathrooms=1.0),
#  Row(name='Modern Room in a Flat with City View - Stratford', price='$46.00', bathrooms=1.0),
#  Row(name='Calm, light space by the river', price='$55.00', bathrooms=0.0),
#  Row(name='Cute Zone2 livingroom w/privacy', price='$30.00', bathrooms=1.0),
#  Row(name='Quiet room with private bathroom facility in SW14.', price='$47.00', bathrooms=1.0),
#  Row(name='MAGICAL URBAN RETREAT sleep up to 5', price='$314.00', bathrooms=2.5),
#  Row(name='Lovely family home', price='$59.00', bathrooms=2.0),
#  Row(name='Light ensuite garden room in East Sheen LondonSW14', price='$50.00', bathrooms=1.0),
#  Row(name='Crystal Palace Double - brand new private bathroom', price='$65.00', bathrooms=1.5),
#  Row(name='Four Poster Large Double Room with ensuite.', price='$76.00', bathrooms=1.0),
#  Row(name='Victorian Cottage in Conservation Area, Greenwich.', price='$727.00', bathrooms=2.0),
#  Row(name='Spacious Flat Great Location', price='$120.00', bathrooms=0.0),
#  Row(name='Quiet Room+Ensuite+Family House Herne Hill London', price='$87.00', bathrooms=1.0),
#  Row(name='Cheap&private London double bedroom', price='$36.00', bathrooms=2.5),
#  Row(name='Exotic house near the Thames short and long stays', price='$333.00', bathrooms=1.5),
#  Row(name='Sole use of luxury Chelsea apartment with security', price='$195.00', bathrooms=2.0),
#  Row(name='Huge, stunning, double room-house Peckham Rye', price='$83.00', bathrooms=1.0),
#  Row(name='NAVAL COTTAGE IN THE HEART OF ROYAL GREENWICH', price='$133.00', bathrooms=1.0),
#  Row(name='Spacious open space flat in the village', price='$124.00', bathrooms=1.0),
#  Row(name="Why not stay here when you're in London?", price='$375.00', bathrooms=2.0),
#  Row(name='Charming 2 Bedroom Apartment in Zone 1.', price='$119.00', bathrooms=1.0),
#  Row(name='Artist Studio, Kensington Olympia', price='$94.00', bathrooms=1.0),
#  Row(name='Garden flat, Herne Hill Station Square', price='$85.00', bathrooms=1.0),
#  Row(name='Cosy double Room to let in E2', price='$32.00', bathrooms=1.0),
#  Row(name='Lovely en suite loft studio for 5 people!', price='$97.00', bathrooms=1.0),
#  Row(name='Modern Flat on charming Warwick Avenue', price='$132.00', bathrooms=1.0),
#  Row(name='Central London oasis: Large house Kennington Park', price='$510.00', bathrooms=3.0),
#  Row(name='Large Double Bedroom 15 min. to Central London', price='$94.00', bathrooms=1.0),
#  Row(name='Chelsea charming apartment', price='$135.00', bathrooms=1.0),
#  Row(name='Bright sunny room near the river, FREE Breakfast', price='$50.00', bathrooms=1.0),
#  Row(name='Artistic Flat in the Heart of West London', price='$624.00', bathrooms=2.0),
#  Row(name='Wimbledon Tennis Double Ensuite Bedroom', price='$34.00', bathrooms=1.0),
#  Row(name='Cozy Family Home  an ideal North London Base', price='$145.00', bathrooms=2.5),
#  Row(name='SOPHISTICATED BOUTIQUE APARTMENT', price='$586.00', bathrooms=2.0),
#  Row(name='Sip Tea at a Stylish Regency Apartment in Camden', price='$149.00', bathrooms=1.0),
#  Row(name='Gorgeous flat in West Kensington', price='$90.00', bathrooms=1.0),
#  Row(name='Cosy single room in Twickenham', price='$39.00', bathrooms=1.0),
#  Row(name='Lovely large Room in Twickenham TW2', price='$42.00', bathrooms=1.0),
#  Row(name='Architect-designed 1 bed apartment', price='$100.00', bathrooms=1.0),
#  Row(name='Double room close to Wimbledon court - free parkin', price='$50.00', bathrooms=1.0),
#  Row(name='Room with private bathroom in modern apartment', price='$53.00', bathrooms=1.5),
#  Row(name='Clapham cosy double room available', price='$42.00', bathrooms=1.0),
#  Row(name='Large family house 3 double bedrooms', price='$270.00', bathrooms=3.0),
#  Row(name='Bright Twin Room in Victorian house /Zone 2', price='$60.00', bathrooms=1.5),
#  Row(name='Huge 5 double bedroom flat, historic building', price='$142.00', bathrooms=1.5),
#  Row(name='Whitechapel ensuite triple room & great breakfast', price='$102.00', bathrooms=1.0),
#  Row(name='Studio with Balcony near Shoreditch', price='$59.00', bathrooms=1.0),
#  Row(name='Brand new luxury 1BD flat. Superfast wifi!!', price='$147.00', bathrooms=1.0),
#  Row(name='Bright & Charming Victorian flat w/Deck', price='$110.00', bathrooms=1.0),
#  Row(name='Cosy Double Room in Brixton  - C', price='$59.00', bathrooms=1.0),
#  Row(name='Stylish Single City Room w/Ensuite', price='$40.00', bathrooms=1.0),
#  Row(name='Large , Bright, Bedroom with private bathroom', price='$54.00', bathrooms=1.0),
#  Row(name='Private double room, 5 mins walk from tube station', price='$53.00', bathrooms=1.5),
#  Row(name='Home from home in Crouch End', price='$105.00', bathrooms=1.0),
#  Row(name='Beautiful Silver Room near London Centre', price='$34.00', bathrooms=1.0),
#  Row(name='Central, peaceful house & garden', price='$36.00', bathrooms=1.0),
#  Row(name="Magic, cosy Artist's Lair, Broadway Market", price='$111.00', bathrooms=1.0),
#  Row(name='Spacious flat with city views', price='$216.00', bathrooms=1.5),
#  Row(name='Stylish family house near Park, sleeps 7, E London', price='$675.00', bathrooms=2.5),
#  Row(name='Spacious room in Southgate, North London', price='$42.00', bathrooms=1.0),
#  Row(name='Lovely bright room in family house. Females only', price='$34.00', bathrooms=1.0),
#  Row(name='1 Db Bedroom in a 2 Bed 2 Bath Flat - Refurbished', price='$50.00', bathrooms=1.0),
#  Row(name='Luxury bedroom & ensuite, parking', price='$72.00', bathrooms=1.0),
#  Row(name='Stunning Chelsea penthouse: 2 bedrooms 2 bathrooms', price='$364.00', bathrooms=2.0),
#  Row(name='Superb Clapham Junction flat', price='$72.00', bathrooms=1.0),
#  Row(name='Room in modern cottage with garden', price='$53.00', bathrooms=1.0),
#  Row(name='Lovely Cosy Bright flat, great location near tube', price='$118.00', bathrooms=1.0),
#  Row(name='Beautiful Sun Shiny Flat in Camden', price='$51.00', bathrooms=1.0),
#  Row(name='3/ Single room  Earlsfield  (Wimbledon area)', price='$36.00', bathrooms=2.0),
#  Row(name='2 bedroom Mayfair flat on prestigious Mount street', price='$618.00', bathrooms=2.0),
#  Row(name='Twin room 2 mins from Clapham South', price='$50.00', bathrooms=1.5),
#  Row(name='Comfortable Clapton Family Home', price='$157.00', bathrooms=2.0),
#  Row(name='3 Double Bedroom FAMILLY APT CLOSE TO NOTTINGHILL', price='$203.00', bathrooms=2.0),
#  Row(name='Lovely 3 Double Bed, 3 Bath with Garden. N6', price='$130.00', bathrooms=1.0),
#  Row(name='Stylish & Spacious Two Bed Flat, De Beauvoir Town', price='$136.00', bathrooms=1.0),
#  Row(name='Platform 9 3/4 by condokeeper', price='$186.00', bathrooms=1.5),
#  Row(name='Notting Hill & Amazing Views...', price='$144.00', bathrooms=1.0),
#  Row(name='Double room with private en-suite & own entrance', price='$68.00', bathrooms=1.5),
#  Row(name='Single bedroom in two-bedroom flat', price='$34.00', bathrooms=1.0),
#  Row(name='Fantastic double room in Richmond', price='$49.00', bathrooms=1.0),
#  Row(name='Zone 1, balcony & 6 mins to tube', price='$59.00', bathrooms=1.0),
#  Row(name='COOL, ENTIRE STUDIO FLAT CAMDEN NW1, OWN ENTRANCE', price='$117.00', bathrooms=1.0),
#  Row(name='Room in charming Victorian house', price='$59.00', bathrooms=1.5),
#  Row(name="Byrne's Self catering grd fl flat plus patio room", price='$86.00', bathrooms=1.0),
#  Row(name="CAMARA'S HOUSE", price='$58.00', bathrooms=1.0),
#  Row(name='Explore London: 2 Bedroom House in London', price='$171.00', bathrooms=1.5),
#  Row(name='Greater London family house', price='$180.00', bathrooms=2.5),
#  Row(name='Amazing double room near BrickLane', price='$73.00', bathrooms=1.0),
#  Row(name='Cosy two bedrooms flat near London Fields', price='$117.00', bathrooms=1.0),
#  Row(name='Beautiful Queens Park 4 Bed House', price='$525.00', bathrooms=3.5),
#  Row(name='Gorgeous 2 Bed/2 Bath London Home', price='$195.00', bathrooms=2.0),
#  Row(name='Single Room near to Wimbledon, Morden Raynes Park', price='$50.00', bathrooms=1.0),
#  Row(name='Cosy Bedroom, private bathroom (wk/mnth discounts)', price='$54.00', bathrooms=1.0),
#  Row(name='Beautiful Wimbledon Village Flat', price='$133.00', bathrooms=1.0),
#  Row(name='Beautiful home in Columbia Road, Hackney', price='$144.00', bathrooms=1.0),
#  Row(name='Marylebone Centrally Located', price='$105.00', bathrooms=1.0),
#  Row(name="Stylish studio in Shepherd's Bush", price='$107.00', bathrooms=1.0),
#  Row(name='Gorgeous Flat - Park Views & Private Bathroom', price='$68.00', bathrooms=1.0),
#  Row(name='London Eye 3 Bedroom Penthouse', price='$375.00', bathrooms=2.5),
#  Row(name='Amazing Central East London 2 Bedroom Flat', price='$120.00', bathrooms=1.0),
#  Row(name='Stunning Historic Church Flat: Room in Shared Flat', price='$66.00', bathrooms=1.0),
#  Row(name='Georgian villa next to trendy Shoreditch,  Hoxton', price='$450.00', bathrooms=2.0),
#  Row(name='London Eye View', price='$99.00', bathrooms=1.0),
#  Row(name='Luxurious apt;  Zone 2, one stop London Bridge!', price='$115.00', bathrooms=1.0),
#  Row(name='Private room Shorditch', price='$84.00', bathrooms=1.0),
#  Row(name='Modern spacious room in heart of East London', price='$55.00', bathrooms=1.0),
#  ...]

# %%
# 7. Get the highest listing price in this dataset
# Consider using the "max" function from "pyspark.sql.functions"
from pyspark.sql.functions import max

listings_with_price \
    .select(max(col('price_numeric'))) \
    .show()
# Out:
# +------------------+
# |max(price_numeric)|
# +------------------+
# |         1085147.0|
# +------------------+

# %%
# 8. Get the name and a price of property with the highest price
# Try to use "collect" method to get the highest price first, and then use it in a "filter" call 
from pyspark.sql.functions import max

res = listings_with_price \
    .select(max('price_numeric').alias('max_price')) \
    .collect()

max_price = res[0]['max_price']

listings_with_price \
    .filter(col('price_numeric') == max_price) \
    .select('name', 'price_numeric') \
    .show()
# Out:
# ---------------------------------------------------------------------------
# AnalysisException                         Traceback (most recent call last)
# Cell In[33], line 4
#       1 # 8. Get the name and a price of property with the highest price
#       2 # Try to use "collect" method to get the highest price first, and then use it in a "filter" call
#       3 listings_with_price \
# ----> 4     .select(col('name'), max(col('price_numeric'))) \
#       5     .show()
#
# File ~/Documents/Programming/ztm-data-engineering/venv/lib/python3.14/site-packages/pyspark/sql/classic/dataframe.py:1015, in DataFrame.select(self, *cols)
#    1014 def select(self, *cols: "ColumnOrName") -> ParentDataFrame:  # type: ignore[misc]
# -> 1015     jdf = self._jdf.select(self._jcols(*cols))
#    1016     return DataFrame(jdf, self.sparkSession)
#
# File ~/Documents/Programming/ztm-data-engineering/venv/lib/python3.14/site-packages/py4j/java_gateway.py:1362, in JavaMember.__call__(self, *args)
#    1356 command = proto.CALL_COMMAND_NAME +\
#    1357     self.command_header +\
#    1358     args_command +\
#    1359     proto.END_COMMAND_PART
#    1361 answer = self.gateway_client.send_command(command)
# -> 1362 return_value = get_return_value(
#    1363     answer, self.gateway_client, self.target_id, self.name)
#    1365 for temp_arg in temp_args:
#    1366     if hasattr(temp_arg, "_detach"):
#
# File ~/Documents/Programming/ztm-data-engineering/venv/lib/python3.14/site-packages/pyspark/errors/exceptions/captured.py:269, in capture_sql_exception.<locals>.deco(*a, **kw)
#     265 converted = convert_exception(e.java_exception)
#     266 if not isinstance(converted, UnknownException):
#     267     # Hide where the exception came from that shows a non-Pythonic
#     268     # JVM exception message.
# --> 269     raise converted from None
#     270 else:
#     271     raise
#
# AnalysisException: [MISSING_GROUP_BY] The query does not include a GROUP BY clause. Add GROUP BY or turn it into the window functions using OVER clauses. SQLSTATE: 42803;
# Aggregate [name#5, max(price_numeric#339) AS max(price_numeric)#354]
# +- Project [id#0L, listing_url#1, scrape_id#2L, last_scraped#3, source#4, name#5, description#6, neighborhood_overview#7, picture_url#8, host_id#9, host_url#10, host_name#11, host_since#12, host_location#13, host_about#14, host_response_time#15, host_response_rate#16, host_acceptance_rate#17, host_is_superhost#18, host_thumbnail_url#19, host_picture_url#20, host_neighbourhood#21, host_listings_count#22, host_total_listings_count#23, host_verifications#24, ... 55 more fields]
#    +- Relation [id#0L,listing_url#1,scrape_id#2L,last_scraped#3,source#4,name#5,description#6,neighborhood_overview#7,picture_url#8,host_id#9,host_url#10,host_name#11,host_since#12,host_location#13,host_about#14,host_response_time#15,host_response_rate#16,host_acceptance_rate#17,host_is_superhost#18,host_thumbnail_url#19,host_picture_url#20,host_neighbourhood#21,host_listings_count#22,host_total_listings_count#23,host_verifications#24,... 54 more fields] csv

# %%
# 9. Get the number of hosts in the dataset

# %%
# 10. Get listings with a first review in 2024
# Consider using the "year" function from "pyspark.sql.functions"
